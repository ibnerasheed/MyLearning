# %%
import pandas as pd
import numpy as np
import math
import os
import datetime

from scipy.spatial.distance import cdist
from scipy.fftpack import fft
from sklearn.manifold import MDS

import matplotlib.pyplot as plt
import matplotlib.cm as cm
plt.style.use('seaborn-whitegrid')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (6.0, 4.0) # set default size of plots
import matplotlib.pyplot as plt

from scipy.spatial.distance import pdist, squareform

# %%
# ## Mount Google drive folder
# from google.colab import drive
# drive.mount('/content/drive', force_remount = True)

# %%
# ## Setup working directory and data directory
# DIR = '/content/drive/MyDrive/Colab Notebooks/MAHE/MSIS Coursework/Miniprojects/Adil'
# os.chdir(DIR)

# %%
## Read data
df = pd.read_csv(r"C:\Users\ibner\Downloads\New folder\data.csv", sep=",", header=0)
df[['date', 'timestamp']] = df['time'].str.split('\s+', expand = True)
df.drop(['time'], axis = 1, inplace = True)
df['date'] =  pd.to_datetime(df['date'], format='%d-%m-%Y')
df['timestamp'] =  pd.to_datetime(df['timestamp'], format='%H:%M').dt.time
df.loc[:, (df.columns != 'date') & (df.columns != 'timestamp')] = df.loc[:, df.columns != 'date'].apply(pd.to_numeric, errors = 'coerce')
print(df.dtypes)
df.head(100)
# Out:
# Cyclone_Inlet_Gas_Temp             float64
# Cyclone_Material_Temp              float64
# Cyclone_Outlet_Gas_draft           float64
# Cyclone_cone_draft                 float64
# Cyclone_Gas_Outlet_Temp            float64
# Cyclone_Inlet_Draft                float64
# date                        datetime64[ns]
# timestamp                           object
# dtype: object
#     Cyclone_Inlet_Gas_Temp  Cyclone_Material_Temp  Cyclone_Outlet_Gas_draft  \
# 0                   867.63                 910.42                   -189.54
# 1                   879.23                 918.14                   -184.33
# 2                   875.67                 924.18                   -181.26
# 3                   875.28                 923.15                   -179.15
# 4                   891.66                 934.26                   -178.32
# ..                     ...                    ...                       ...
# 95                  863.20                 902.56                   -172.64
# 96                  876.41                 911.41                   -175.91
# 97                  873.89                 917.18                   -172.26
# 98                  870.67                 919.84                   -177.01
# 99                  860.73                 909.36                   -174.02
#
#     Cyclone_cone_draft  Cyclone_Gas_Outlet_Temp  Cyclone_Inlet_Draft  \
# 0              -186.04                   852.13              -145.90
# 1              -182.10                   862.53              -149.76
# 2              -166.47                   866.06              -145.01
# 3              -174.83                   865.85              -142.82
# 4              -173.72                   876.06              -143.39
# ..                 ...                      ...                  ...
# 95             -164.10                   854.67              -142.92
# 96             -171.55                   862.48              -144.66
# 97             -160.11                   865.02              -138.29
# 98             -146.57                   862.77              -143.80
# 99             -139.30                   852.06              -137.11
#
#          date timestamp
# 0  2017-01-01  00:00:00
# 1  2017-01-01  00:05:00
# 2  2017-01-01  00:10:00
# 3  2017-01-01  00:15:00
# 4  2017-01-01  00:20:00
# ..        ...       ...
# 95 2017-01-01  07:55:00
# 96 2017-01-01  08:00:00
# 97 2017-01-01  08:05:00
# 98 2017-01-01  08:10:00
# 99 2017-01-01  08:15:00
#
# [100 rows x 8 columns]

# %%
## Plot percentage of missing values (NaNs) for each feature
cutoff = 30
fig = plt.figure(figsize=(6, 6))
percent_missing = (df.isna().sum() / df.shape[0]) * 100
percent_missing.plot(kind = 'bar', color = cm.rainbow(np.linspace(0, 1, 2))[(percent_missing <= cutoff).values.astype(int)])
plt.plot(np.arange(df.shape[1]), np.repeat(cutoff, df.shape[1]), 'g--') 
fig.suptitle('Percentage Missing Values Across All Features', fontsize = 20)
plt.xlabel('Feature', fontsize = 16)
plt.ylabel('% Missing Values', fontsize = 16)
# Out:
# Text(0, 0.5, '% Missing Values')

# %%
## Linear interpolation for all column
df['Cyclone_Inlet_Gas_Temp'] = df['Cyclone_Inlet_Gas_Temp'].interpolate(method = 'linear')
df["Cyclone_Material_Temp"] = df["Cyclone_Material_Temp"].interpolate(method='linear')
df["Cyclone_Outlet_Gas_draft"] = df["Cyclone_Outlet_Gas_draft"].interpolate(method='linear')
df["Cyclone_cone_draft"] = df["Cyclone_cone_draft"].interpolate(method='linear')
df["Cyclone_Gas_Outlet_Temp"] = df["Cyclone_Gas_Outlet_Temp"].interpolate(method='linear')
df["Cyclone_Inlet_Draft"] = df["Cyclone_Inlet_Draft"].interpolate(method='linear')
(df.isna().sum() / df.shape[0]) * 100
# Out:
# Cyclone_Inlet_Gas_Temp      0.0
# Cyclone_Material_Temp       0.0
# Cyclone_Outlet_Gas_draft    0.0
# Cyclone_cone_draft          0.0
# Cyclone_Gas_Outlet_Temp     0.0
# Cyclone_Inlet_Draft         0.0
# date                        0.0
# timestamp                   0.0
# dtype: float64

# %%
df
# Out:
#         Cyclone_Inlet_Gas_Temp  Cyclone_Material_Temp  \
# 0                       867.63                 910.42
# 1                       879.23                 918.14
# 2                       875.67                 924.18
# 3                       875.28                 923.15
# 4                       891.66                 934.26
# ...                        ...                    ...
# 377714                  899.42                 919.79
# 377715                  879.90                 895.02
# 377716                  887.20                 895.70
# 377717                  908.50                 916.33
# 377718                  880.86                 905.31
#
#         Cyclone_Outlet_Gas_draft  Cyclone_cone_draft  Cyclone_Gas_Outlet_Temp  \
# 0                        -189.54             -186.04                   852.13
# 1                        -184.33             -182.10                   862.53
# 2                        -181.26             -166.47                   866.06
# 3                        -179.15             -174.83                   865.85
# 4                        -178.32             -173.72                   876.06
# ...                          ...                 ...                      ...
# 377714                   -224.07             -209.77                   901.01
# 377715                   -228.04             -211.28                   878.08
# 377716                   -230.11             -214.65                   885.32
# 377717                   -231.51             -218.09                   906.20
# 377718                   -235.02             -219.44                   882.10
#
#         Cyclone_Inlet_Draft       date timestamp
# 0                   -145.90 2017-01-01  00:00:00
# 1                   -149.76 2017-01-01  00:05:00
# 2                   -145.01 2017-01-01  00:10:00
# 3                   -142.82 2017-01-01  00:15:00
# 4                   -143.39 2017-01-01  00:20:00
# ...                     ...        ...       ...
# 377714              -175.15 2020-08-07  11:55:00
# 377715              -176.94 2020-08-07  12:00:00
# 377716              -179.18 2020-08-07  12:05:00
# 377717              -181.96 2020-08-07  12:10:00
# 377718              -184.02 2020-08-07  12:15:00
#
# [377719 rows x 8 columns]

# %%
## Calculate FFT of each sample, followed by absolute value
## of Foruier coefficients and a pairwise distance between
## samples
fftval = df.groupby("date").apply(lambda x:  fft(x["Cyclone_Outlet_Gas_draft"].values))
#fftval = fftval[:-1].to_numpy()
fftval = np.array([x for x in fftval.values if len(x) == 288])
fftmag = np.abs(fftval)
dist = squareform(pdist(np.abs(fftmag), 'euclidean'))

# %%
dff = pd.DataFrame(dist)
dff
# Out:
#               0             1             2             3             4     \
# 0         0.000000   2002.805484   1734.344650   3840.106691   2682.251778
# 1      2002.805484      0.000000    797.109913   3310.084142   1074.898569
# 2      1734.344650    797.109913      0.000000   3230.213638   1298.974993
# 3      3840.106691   3310.084142   3230.213638      0.000000   3264.968017
# 4      2682.251778   1074.898569   1298.974993   3264.968017      0.000000
# ...            ...           ...           ...           ...           ...
# 1306  15602.139762  13816.722292  14129.485684  13355.717741  13206.232242
# 1307  17910.748971  16143.872570  16458.340151  15665.009752  15566.476979
# 1308  15602.451038  13793.624415  14118.310350  13486.374018  13189.113773
# 1309  15004.003640  13211.576030  13551.025452  12801.374087  12608.609545
# 1310  14775.605911  12997.759713  13307.841348  12600.018132  12419.268994
#
#               5             6            7             8             9     \
# 0      4947.371213   6635.458242  9314.067182   6138.702196   5723.538007
# 1      3276.850193   4974.170787  7628.852997   4355.137333   4020.121489
# 2      3517.073156   5215.128825  7899.480032   4658.369496   4316.257962
# 3      3582.270791   4651.019059  6790.717192   4611.692364   4266.704723
# 4      2698.286139   4469.590305  7055.220474   3800.527931   3540.430081
# ...            ...           ...          ...           ...           ...
# 1306  11004.425584   9258.327902  6987.345452   9610.222581  10006.826724
# 1307  13386.565720  11504.764757  9254.797148  11956.653362  12287.831803
# 1308  11028.141413   9321.606172  7131.997178   9620.166774  10043.410786
# 1309  10373.003476   8842.708733  6609.259567   9056.449373   9526.535267
# 1310  10226.032503   8429.499396  6414.073557   8798.291765   9195.698252
#
#       ...          1301          1302          1303          1304  \
# 0     ...  18823.772245  19307.530394  23241.088640  17700.366540
# 1     ...  16996.865082  17478.939644  22981.105062  15887.058741
# 2     ...  17340.239887  17823.090808  22886.982511  16227.208891
# 3     ...  16720.460366  17326.613517  20413.379387  15702.572610
# 4     ...  16396.624598  16883.866982  22784.112391  15297.630388
# ...   ...           ...           ...           ...           ...
# 1306  ...   3763.868199   4455.098901  22332.983119   2977.645420
# 1307  ...   2824.531058   3227.142065  22990.183349   2205.922387
# 1308  ...   3628.473344   4126.686409  23029.972863   2655.858343
# 1309  ...   4385.951395   5019.821801  22880.657587   3643.301805
# 1310  ...   4685.555373   5212.914178  22257.070838   3553.636933
#
#               1305          1306          1307          1308          1309  \
# 0     16957.898376  15602.139762  17910.748971  15602.451038  15004.003640
# 1     15121.666107  13816.722292  16143.872570  13793.624415  13211.576030
# 2     15449.337467  14129.485684  16458.340151  14118.310350  13551.025452
# 3     14935.030864  13355.717741  15665.009752  13486.374018  12801.374087
# 4     14506.321867  13206.232242  15566.476979  13189.113773  12608.609545
# ...            ...           ...           ...           ...           ...
# 1306   2970.063408      0.000000   2865.183272   1428.281698   2176.473271
# 1307   3495.720259   2865.183272      0.000000   3053.760495   3997.320016
# 1308   2659.131429   1428.281698   3053.760495      0.000000   2111.271601
# 1309   3240.799412   2176.473271   3997.320016   2111.271601      0.000000
# 1310   3404.714749   1829.508933   3562.013662   1998.347283   2457.130963
#
#               1310
# 0     14775.605911
# 1     12997.759713
# 2     13307.841348
# 3     12600.018132
# 4     12419.268994
# ...            ...
# 1306   1829.508933
# 1307   3562.013662
# 1308   1998.347283
# 1309   2457.130963
# 1310      0.000000
#
# [1311 rows x 1311 columns]

# %%
radius=[]
for i in range(len(dff)):
    x=dff.sort_values(by=i, axis = 1).iloc[i:i+1,1:37]
    radius.append(x.iloc[:, -1].values)
radius
# Out:
# [array([1628.00682541]),
#  array([1496.16702575]),
#  array([1472.97216703]),
#  array([2669.4446819]),
#  array([1647.00731776]),
#  array([2278.83353208]),
#  array([2238.38501554]),
#  array([2805.88813853]),
#  array([1871.75667094]),
#  array([1899.27849793]),
#  array([1673.03439846]),
#  array([1597.24273281]),
#  array([1713.83364366]),
#  array([1560.73604699]),
#  array([1565.37719831]),
#  array([2161.63781182]),
#  array([2065.68381892]),
#  array([1717.63283112]),
#  array([3441.45473118]),
#  array([2517.45144895]),
#  array([1437.28200636]),
#  array([4085.34239731]),
#  array([19882.34787676]),
#  array([1503.79562882]),
#  array([9610.21886876]),
#  array([12395.64275666]),
#  array([1801.43064085]),
#  array([4541.66325844]),
#  array([1604.35312112]),
#  array([1595.3418433]),
#  array([1701.28186569]),
#  array([4182.71177741]),
#  array([1966.72683731]),
#  array([1902.0045237]),
#  array([1518.13737935]),
#  array([1635.97643998]),
#  array([1642.92457687]),
#  array([1586.46443756]),
#  array([4254.09202868]),
#  array([2298.81373516]),
#  array([1764.36203819]),
#  array([2257.40475089]),
#  array([2272.15142347]),
#  array([1990.5404746]),
#  array([1995.75761198]),
#  array([1415.18768461]),
#  array([2135.97982922]),
#  array([1862.21600895]),
#  array([2009.66851048]),
#  array([1954.95889326]),
#  array([2306.8499539]),
#  array([1543.86898923]),
#  array([2152.54304748]),
#  array([2073.71465308]),
#  array([1999.93670352]),
#  array([3127.60343691]),
#  array([2539.97627944]),
#  array([2917.99929835]),
#  array([1828.1824436]),
#  array([2791.90450415]),
#  array([14368.44722234]),
#  array([1598.47364774]),
#  array([1942.87580434]),
#  array([1704.95500962]),
#  array([1497.69944811]),
#  array([7685.7928081]),
#  array([3354.69083971]),
#  array([1586.02301666]),
#  array([1731.79360408]),
#  array([1903.0319374]),
#  array([7149.46069574]),
#  array([1903.88818064]),
#  array([2459.81303359]),
#  array([1764.84986137]),
#  array([2216.62998282]),
#  array([1917.5741824]),
#  array([2538.07685994]),
#  array([2187.52364208]),
#  array([3026.26949859]),
#  array([17371.45507794]),
#  array([1281.68020941]),
#  array([2568.78798548]),
#  array([1146.69438849]),
#  array([15239.93698249]),
#  array([4159.1186197]),
#  array([1972.64683011]),
#  array([1682.94471396]),
#  array([5858.30777729]),
#  array([11248.02648672]),
#  array([3020.85810449]),
#  array([3322.19242788]),
#  array([2192.25449313]),
#  array([6120.09129033]),
#  array([5611.65943176]),
#  array([16878.54564268]),
#  array([1144.60099256]),
#  array([8254.49909711]),
#  array([2355.82051253]),
#  array([1563.54413068]),
#  array([2240.58193612]),
#  array([4299.1010135]),
#  array([1791.37020861]),
#  array([1458.41083912]),
#  array([1484.45837216]),
#  array([2153.93031241]),
#  array([1627.77417723]),
#  array([2116.71740758]),
#  array([4237.27927326]),
#  array([5385.66754321]),
#  array([3015.06493401]),
#  array([2268.40740833]),
#  array([2460.84338633]),
#  array([1870.88432243]),
#  array([2044.56986486]),
#  array([1757.86789593]),
#  array([1769.34977413]),
#  array([1549.17845017]),
#  array([1583.17381077]),
#  array([5115.89435083]),
#  array([1939.70668679]),
#  array([1872.661832]),
#  array([1430.05295426]),
#  array([1493.20827885]),
#  array([1508.02672417]),
#  array([1668.82349058]),
#  array([2700.2049389]),
#  array([1777.14122993]),
#  array([1923.6715528]),
#  array([4171.50999825]),
#  array([1902.61698863]),
#  array([1937.23996341]),
#  array([2188.69301931]),
#  array([2008.60144047]),
#  array([1737.01490362]),
#  array([4585.57220027]),
#  array([3319.84927821]),
#  array([2859.24684075]),
#  array([1964.63711012]),
#  array([8113.14159743]),
#  array([5701.63179665]),
#  array([354.05565431]),
#  array([341.68205889]),
#  array([358.89991006]),
#  array([408.12339075]),
#  array([396.69138651]),
#  array([401.80268036]),
#  array([393.91797445]),
#  array([433.10480153]),
#  array([593.40943416]),
#  array([10106.65706329]),
#  array([13308.69767878]),
#  array([9051.41685071]),
#  array([2430.86452129]),
#  array([7139.798201]),
#  array([5654.55195065]),
#  array([2602.66398767]),
#  array([4607.87088875]),
#  array([1869.89978381]),
#  array([15546.84751751]),
#  array([11329.89585869]),
#  array([1915.40155759]),
#  array([2789.34492988]),
#  array([10448.20346752]),
#  array([1661.70490154]),
#  array([14455.17412914]),
#  array([1419.19227388]),
#  array([10494.91306274]),
#  array([1521.06519925]),
#  array([1546.69983212]),
#  array([1489.27730883]),
#  array([1705.05450917]),
#  array([1534.99662215]),
#  array([4924.8059635]),
#  array([2420.25392941]),
#  array([3976.69376896]),
#  array([3830.23808136]),
#  array([6112.03383959]),
#  array([1633.08697499]),
#  array([3015.4738424]),
#  array([1398.72532027]),
#  array([3606.92287726]),
#  array([1922.90517791]),
#  array([2262.1446232]),
#  array([2056.89458288]),
#  array([1994.88356097]),
#  array([3170.32250066]),
#  array([1942.52008025]),
#  array([2158.42216132]),
#  array([1758.14030974]),
#  array([1933.8415339]),
#  array([1931.78455925]),
#  array([2258.81634974]),
#  array([1941.09087722]),
#  array([3039.21291427]),
#  array([1808.1923471]),
#  array([1838.6648941]),
#  array([1769.71374823]),
#  array([1770.076071]),
#  array([1778.70395879]),
#  array([1850.77102009]),
#  array([13018.70912549]),
#  array([1859.99131041]),
#  array([1782.97136418]),
#  array([1881.54839232]),
#  array([1964.98954944]),
#  array([1832.13961683]),
#  array([1846.59873943]),
#  array([2113.44270176]),
#  array([5544.54636646]),
#  array([4030.86152397]),
#  array([2340.96475948]),
#  array([20312.79509564]),
#  array([2352.571947]),
#  array([3056.10855388]),
#  array([1797.99576332]),
#  array([1895.29815236]),
#  array([8479.9708076]),
#  array([1767.11278685]),
#  array([2141.10365966]),
#  array([1900.08943435]),
#  array([4139.63955733]),
#  array([1904.80065424]),
#  array([1894.61904158]),
#  array([1979.802003]),
#  array([2347.07853635]),
#  array([1982.5754521]),
#  array([2043.61974044]),
#  array([2033.42019159]),
#  array([1737.09902117]),
#  array([1878.83421336]),
#  array([1662.0174891]),
#  array([7528.34037893]),
#  array([3401.47785979]),
#  array([3010.62012368]),
#  array([1683.09034759]),
#  array([2043.33110098]),
#  array([3059.7146115]),
#  array([2118.93128395]),
#  array([2262.25326444]),
#  array([3066.86723802]),
#  array([1492.06823517]),
#  array([1854.76359876]),
#  array([1625.98264046]),
#  array([1605.31777429]),
#  array([1562.38608033]),
#  array([1640.8470664]),
#  array([1868.9110252]),
#  array([2051.00173743]),
#  array([1495.66155222]),
#  array([1476.712854]),
#  array([1493.67554515]),
#  array([17432.12736319]),
#  array([1717.50733839]),
#  array([1778.27059291]),
#  array([12564.96056602]),
#  array([4727.01100677]),
#  array([10965.92153116]),
#  array([1673.11894883]),
#  array([1667.23901843]),
#  array([11722.83609946]),
#  array([1591.3149056]),
#  array([8046.54004048]),
#  array([3013.07006319]),
#  array([410.02836639]),
#  array([320.61976214]),
#  array([322.56300421]),
#  array([341.21961106]),
#  array([337.86060678]),
#  array([344.45052479]),
#  array([382.38565956]),
#  array([377.81081789]),
#  array([375.01714787]),
#  array([428.26593321]),
#  array([421.42214442]),
#  array([484.30995169]),
#  array([437.96272008]),
#  array([468.79093619]),
#  array([468.20896675]),
#  array([404.83611508]),
#  array([393.4506442]),
#  array([421.7540285]),
#  array([364.94206236]),
#  array([376.80136446]),
#  array([505.64568635]),
#  array([362.73434007]),
#  array([415.69214817]),
#  array([305.50536516]),
#  array([398.1543055]),
#  array([445.5146816]),
#  array([790.54978644]),
#  array([1762.43139086]),
#  array([16678.99373303]),
#  array([17724.25514372]),
#  array([3503.81785833]),
#  array([2709.29456771]),
#  array([6008.65399541]),
#  array([2370.39671287]),
#  array([2579.84705717]),
#  array([2534.19650416]),
#  array([16252.70508039]),
#  array([3764.05817659]),
#  array([2114.42995438]),
#  array([1966.63463698]),
#  array([11352.90365824]),
#  array([8181.43928026]),
#  array([2349.14067785]),
#  array([1779.58609907]),
#  array([6485.76172848]),
#  array([1809.12601256]),
#  array([1996.86471898]),
#  array([3207.89724409]),
#  array([2009.46054036]),
#  array([2066.59886918]),
#  array([1918.69835499]),
#  array([2001.42039283]),
#  array([2009.46054036]),
#  array([2227.9416641]),
#  array([2683.48507952]),
#  array([1972.486469]),
#  array([5391.44184296]),
#  array([2098.33794573]),
#  array([2179.59452492]),
#  array([2735.55417179]),
#  array([2557.83053645]),
#  array([3887.6964476]),
#  array([5258.51630404]),
#  array([2146.38583266]),
#  array([2805.15755594]),
#  array([2359.45296987]),
#  array([7996.21815335]),
#  array([15201.86010331]),
#  array([5365.95075603]),
#  array([8715.26397874]),
#  array([435.63464506]),
#  array([417.11806328]),
#  array([338.61477988]),
#  array([504.95962003]),
#  array([358.13729605]),
#  array([1637.2119939]),
#  array([292.33587532]),
#  array([1584.86451563]),
#  array([10249.0397398]),
#  array([11703.0591263]),
#  array([6139.81415976]),
#  array([3035.70583942]),
#  array([11698.61794805]),
#  array([7904.40709178]),
#  array([4512.873138]),
#  array([2508.92180245]),
#  array([2637.14665367]),
#  array([2281.44690646]),
#  array([1896.23672724]),
#  array([2010.62068446]),
#  array([2656.87962376]),
#  array([1774.55353507]),
#  array([1811.10126967]),
#  array([1815.01133241]),
#  array([1912.26797858]),
#  array([10815.0454072]),
#  array([2235.08351]),
#  array([8273.47711589]),
#  array([7204.45409464]),
#  array([5197.79939659]),
#  array([2392.47979674]),
#  array([5454.81069246]),
#  array([1894.47559711]),
#  array([2071.2562584]),
#  array([3138.31177304]),
#  array([1860.409955]),
#  array([2116.89159806]),
#  array([1894.47559711]),
#  array([6782.87684776]),
#  array([3874.98416528]),
#  array([1912.65934586]),
#  array([1911.64944491]),
#  array([1824.30825181]),
#  array([2500.9960215]),
#  array([2133.46984875]),
#  array([3690.54128311]),
#  array([13103.36626814]),
#  array([2823.34226684]),
#  array([3663.51853976]),
#  array([3220.29261591]),
#  array([3089.86766388]),
#  array([1926.60907334]),
#  array([1824.84110869]),
#  array([3214.61743887]),
#  array([1876.64904906]),
#  array([2405.41045413]),
#  array([1993.85038457]),
#  array([1771.99417911]),
#  array([1678.00505205]),
#  array([2158.96214384]),
#  array([5824.3074099]),
#  array([10421.46230939]),
#  array([22056.04563992]),
#  array([15726.86102889]),
#  array([2073.86673485]),
#  array([1880.70980348]),
#  array([1956.39959076]),
#  array([5495.39624515]),
#  array([2360.46771055]),
#  array([2082.35551676]),
#  array([1993.7848679]),
#  array([1871.68629057]),
#  array([13740.98776544]),
#  array([1962.53086024]),
#  array([1910.27845633]),
#  array([2150.20528337]),
#  array([12676.98047855]),
#  array([1756.57469953]),
#  array([19712.90166293]),
#  array([2369.57115045]),
#  array([12615.89779593]),
#  array([8752.31307523]),
#  array([2423.13562897]),
#  array([5877.1896828]),
#  array([2515.04575398]),
#  array([5552.42201636]),
#  array([1818.49281935]),
#  array([20577.17226184]),
#  array([1776.31991747]),
#  array([6743.20314237]),
#  array([3888.87210719]),
#  array([2538.54951158]),
#  array([1895.29815236]),
#  array([2026.80169017]),
#  array([1898.70316756]),
#  array([1735.24659118]),
#  array([11037.15242314]),
#  array([9085.24048236]),
#  array([1851.67103359]),
#  array([2286.78230762]),
#  array([1811.32606802]),
#  array([2994.14972451]),
#  array([7231.21638811]),
#  array([2258.26436702]),
#  array([1748.56278055]),
#  array([2240.34296133]),
#  array([2016.50769557]),
#  array([2685.82936399]),
#  array([3405.52121227]),
#  array([8175.30112266]),
#  array([5520.67509713]),
#  array([2080.3363135]),
#  array([2139.21933024]),
#  array([1998.75325479]),
#  array([2395.6645256]),
#  array([5938.46156208]),
#  array([2344.32863787]),
#  array([2339.75010115]),
#  array([2213.94675562]),
#  array([3024.83450069]),
#  array([2312.49674471]),
#  array([19673.73649353]),
#  array([2602.06856831]),
#  array([2173.25336929]),
#  array([13055.29537507]),
#  array([2360.75996002]),
#  array([2631.52312235]),
#  array([2131.2882974]),
#  array([4893.87222412]),
#  array([2113.21771825]),
#  array([2409.4209018]),
#  array([3096.97598175]),
#  array([1970.32946082]),
#  array([3663.13516179]),
#  array([12504.43393576]),
#  array([2377.28438481]),
#  array([4684.79957953]),
#  array([3857.33403491]),
#  array([2291.80228606]),
#  array([3925.08892294]),
#  array([2447.57398615]),
#  array([2155.69171195]),
#  array([2596.847511]),
#  array([2040.07219057]),
#  array([2508.11371764]),
#  array([4135.68919164]),
#  array([2146.99092592]),
#  array([2528.82354058]),
#  array([9024.64780337]),
#  array([14801.54133092]),
#  array([4552.72242938]),
#  array([21511.99495174]),
#  array([9066.14620215]),
#  array([1692.49085686]),
#  array([6010.2024133]),
#  array([1867.67101798]),
#  array([1862.09782637]),
#  array([9690.41141773]),
#  array([12622.37466269]),
#  array([10319.90148557]),
#  array([7462.73324588]),
#  array([2413.23454317]),
#  array([2041.70586759]),
#  array([2675.58380088]),
#  array([2573.54454822]),
#  array([2557.83053645]),
#  array([16406.51976853]),
#  array([2700.62717391]),
#  array([2340.36481571]),
#  array([7277.31314709]),
#  array([1977.21365694]),
#  array([6528.1826342]),
#  array([9051.0858894]),
#  array([9882.41185231]),
#  array([4592.20145812]),
#  array([8179.4040112]),
#  array([4168.42438462]),
#  array([4208.72337593]),
#  array([3329.37896401]),
#  array([5832.7298483]),
#  array([4940.74799175]),
#  array([21595.53068571]),
#  array([12130.42570429]),
#  array([5262.18758149]),
#  array([3308.81382288]),
#  array([5202.11455316]),
#  array([19369.32729675]),
#  array([2970.34888425]),
#  array([18106.35088435]),
#  array([2350.66151797]),
#  array([2864.25938306]),
#  array([8812.44410956]),
#  array([4364.51208191]),
#  array([4930.16091789]),
#  array([2885.46511444]),
#  array([5162.42415299]),
#  array([4497.8968433]),
#  array([4897.02702072]),
#  array([4632.79692488]),
#  array([11485.06437695]),
#  array([14677.16290439]),
#  array([1121.29430846]),
#  array([21803.82491324]),
#  array([3419.30627869]),
#  array([2626.06306845]),
#  array([4366.6979558]),
#  array([4992.27248282]),
#  array([3310.51140328]),
#  array([11848.59022443]),
#  array([17766.55934271]),
#  array([3574.41941195]),
#  array([3009.25129691]),
#  array([2137.21512881]),
#  array([7612.01708776]),
#  array([11056.16972038]),
#  array([17357.28013287]),
#  array([6882.39424834]),
#  array([5195.37753044]),
#  array([3322.47591015]),
#  array([1934.77643734]),
#  array([2175.94661858]),
#  array([21770.24725646]),
#  array([2850.40434583]),
#  array([3130.74025548]),
#  array([13173.61754676]),
#  array([7358.30640611]),
#  array([14146.85228193]),
#  array([5389.74115743]),
#  array([2049.74084054]),
#  array([2046.36646116]),
#  array([7499.92804752]),
#  array([2113.97834109]),
#  array([3211.24152272]),
#  array([2381.15808789]),
#  array([2192.95950929]),
#  array([2275.26246913]),
#  array([2589.69753245]),
#  array([2115.39510443]),
#  array([2320.19920483]),
#  array([2404.41690049]),
#  array([8572.66893252]),
#  array([13645.54836276]),
#  array([6214.04151306]),
#  array([7901.77794263]),
#  array([2766.02887739]),
#  array([2494.11580302]),
#  array([4854.64627353]),
#  array([4995.44913023]),
#  array([7816.64764797]),
#  array([7318.98912295]),
#  array([2561.63601746]),
#  array([7833.95730486]),
#  array([3509.516631]),
#  array([2021.14268051]),
#  array([9584.96544694]),
#  array([4644.46778069]),
#  array([3239.4821951]),
#  array([2275.64326627]),
#  array([2633.6795558]),
#  array([2946.20102821]),
#  array([1997.74737444]),
#  array([2591.28972516]),
#  array([3943.41554131]),
#  array([7883.05091073]),
#  array([8330.19506667]),
#  array([5046.55206868]),
#  array([6315.48599602]),
#  array([2777.25316445]),
#  array([2141.5432502]),
#  array([2213.98836825]),
#  array([2863.86865117]),
#  array([14061.72737203]),
#  array([5542.42943642]),
#  array([4415.32953285]),
#  array([667.44904718]),
#  array([2172.9973005]),
#  array([10585.16939636]),
#  array([2735.57947891]),
#  array([2114.32486592]),
#  array([3148.19726922]),
#  array([3478.12689499]),
#  array([3434.93813952]),
#  array([3205.21809138]),
#  array([1766.60351522]),
#  array([2113.39017638]),
#  array([1908.48403264]),
#  array([2003.03411851]),
#  array([1841.64927922]),
#  array([18316.91141535]),
#  array([8917.12026367]),
#  array([17951.72392904]),
#  array([2404.85270595]),
#  array([3215.01631036]),
#  array([2993.64859652]),
#  array([4029.64690167]),
#  array([6239.22224562]),
#  array([2451.49054123]),
#  array([3037.83576274]),
#  array([16430.74036121]),
#  array([4095.53387429]),
#  array([873.96407038]),
#  array([118.30714606]),
#  array([126.18408825]),
#  array([110.58602204]),
#  array([120.86403442]),
#  array([110.38320998]),
#  array([106.65355539]),
#  array([111.56258688]),
#  array([119.46612373]),
#  array([108.35435201]),
#  array([104.93853908]),
#  array([138.14843428]),
#  array([151.81176282]),
#  array([116.81943155]),
#  array([117.46204581]),
#  array([116.34819662]),
#  array([111.06156856]),
#  array([125.23642517]),
#  array([138.07735862]),
#  array([1554.93230847]),
#  array([2029.63978781]),
#  array([10841.60000928]),
#  array([7915.45642076]),
#  array([2553.81370502]),
#  array([2258.81634974]),
#  array([5317.37050658]),
#  array([14750.4710729]),
#  array([2409.32355851]),
#  array([6925.40554614]),
#  array([18941.7128867]),
#  array([2877.64561392]),
#  array([2071.59567161]),
#  array([2248.77294895]),
#  array([2371.49635368]),
#  array([3550.11902461]),
#  array([4900.84441639]),
#  array([4287.98610224]),
#  array([4537.73793058]),
#  array([4335.77708213]),
#  array([19804.99420791]),
#  array([4810.78773423]),
#  array([1945.6876038]),
#  array([4191.47920315]),
#  array([3163.50474104]),
#  array([2069.95179547]),
#  array([2002.29878696]),
#  array([2107.77807913]),
#  array([9470.79910591]),
#  array([1942.53048924]),
#  array([2604.38504584]),
#  array([1905.59497824]),
#  array([2979.00715736]),
#  array([1926.54294613]),
#  array([2062.67442268]),
#  array([10290.52917126]),
#  array([3191.05106867]),
#  array([2451.22049498]),
#  array([1997.25018219]),
#  array([1987.36143977]),
#  array([2206.82272574]),
#  array([2139.58208947]),
#  array([24556.18512722]),
#  array([1444.48424469]),
#  array([1058.77749044]),
#  array([15750.24278679]),
#  array([3362.27742911]),
#  array([1976.23624902]),
#  array([1751.07252673]),
#  array([2360.1902823]),
#  array([8592.17628902]),
#  array([2557.8975951]),
#  array([14920.87368394]),
#  array([2083.48248312]),
#  array([17419.94716794]),
#  array([8116.41693221]),
#  array([1935.86858281]),
#  array([1919.96337904]),
#  array([14455.17412914]),
#  array([1842.79678492]),
#  array([1716.63824641]),
#  array([1740.05734013]),
#  array([1797.53563398]),
#  array([1683.69304247]),
#  array([2038.88787497]),
#  array([1930.57156516]),
#  array([4549.34931249]),
#  array([9142.74957574]),
#  array([2033.19229077]),
#  array([1979.91440171]),
#  array([1862.7322479]),
#  array([1841.15435489]),
#  array([1847.14678105]),
#  array([1875.45358983]),
#  array([1843.12604781]),
#  array([1704.36182654]),
#  array([2953.35821771]),
#  array([1932.87297937]),
#  array([13872.95574169]),
#  array([1744.48863138]),
#  array([2162.40329767]),
#  array([2094.32733604]),
#  array([1960.30092555]),
#  array([5901.16084219]),
#  array([1824.82011098]),
#  array([1842.2294584]),
#  array([1821.01085993]),
#  array([10347.62674021]),
#  array([1913.13126563]),
#  array([2197.92041069]),
#  array([1857.81591434]),
#  array([1644.74236077]),
#  array([1760.52977792]),
#  array([7878.25518852]),
#  array([2309.1758545]),
#  array([2047.15422517]),
#  array([2039.26108541]),
#  array([2086.44413204]),
#  array([6118.78348834]),
#  array([1984.7789448]),
#  array([2931.71488046]),
#  array([2871.53658538]),
#  array([1754.89649257]),
#  array([1858.05228268]),
#  array([1903.31942499]),
#  array([1986.37451735]),
#  array([2020.29953477]),
#  array([13609.11579941]),
#  array([3981.13041504]),
#  array([1872.51006725]),
#  array([6572.12206405]),
#  array([3776.99962854]),
#  array([1912.65934586]),
#  array([2997.34633696]),
#  array([4452.93429465]),
#  array([2002.82257583]),
#  array([1933.10327498]),
#  array([11153.60297972]),
#  array([4799.52863986]),
#  array([2376.40102585]),
#  array([2968.74654359]),
#  array([2030.19827182]),
#  array([1971.91250442]),
#  array([13333.06855895]),
#  array([9580.89517245]),
#  array([3656.32572273]),
#  array([2079.36323164]),
#  array([2021.01929581]),
#  array([1932.47983935]),
#  array([1903.36520368]),
#  array([2386.94946975]),
#  array([9102.17126765]),
#  array([2349.48763684]),
#  array([2072.83799892]),
#  array([1965.58802323]),
#  array([2256.43645956]),
#  array([2037.92293087]),
#  array([1927.70198646]),
#  array([1831.24694928]),
#  array([2202.96759851]),
#  array([1786.45196684]),
#  array([2085.11648661]),
#  array([2094.58205164]),
#  array([20327.46086866]),
#  array([1970.53949536]),
#  array([851.73827264]),
#  array([1149.7762632]),
#  array([542.78788416]),
#  array([512.37793787]),
#  array([236.49745809]),
#  array([1569.37573966]),
#  array([6187.77129152]),
#  array([20915.15806457]),
#  array([2215.82553531]),
#  array([3343.38089126]),
#  array([2733.24301479]),
#  array([2907.28894214]),
#  array([6978.90575223]),
#  array([1996.2009774]),
#  array([2150.67385981]),
#  array([4020.73233591]),
#  array([2427.40453769]),
#  array([1917.03500287]),
#  array([2499.83851549]),
#  array([2221.33898164]),
#  array([3562.54169031]),
#  array([2584.12051773]),
#  array([2160.86114671]),
#  array([3163.56783812]),
#  array([7165.9245326]),
#  array([1997.46527748]),
#  array([2746.02970785]),
#  array([10065.08854274]),
#  array([2209.68445361]),
#  array([2001.22369002]),
#  array([2901.15034968]),
#  array([2053.43668992]),
#  array([2184.63760219]),
#  array([6473.22153276]),
#  array([16404.84191774]),
#  array([2035.27063009]),
#  array([15263.03696439]),
#  array([1971.68570037]),
#  array([2559.78638611]),
#  array([2171.00298765]),
#  array([2503.59980509]),
#  array([7712.39610655]),
#  array([2117.41709605]),
#  array([2333.18215274]),
#  array([1837.07543714]),
#  array([2443.23647317]),
#  array([2020.84874122]),
#  array([2054.11093166]),
#  array([2237.49291822]),
#  array([25402.17340483]),
#  array([20993.82914899]),
#  array([2193.03516896]),
#  array([3344.93633285]),
#  array([2181.31305125]),
#  array([6862.53799745]),
#  array([9703.75589322]),
#  array([3869.36661015]),
#  array([363.67690689]),
#  array([435.92994163]),
#  array([377.4483541]),
#  array([346.99237974]),
#  array([665.3478659]),
#  array([924.58215334]),
#  array([1469.25917798]),
#  array([17983.95717622]),
#  array([1601.25449079]),
#  array([1450.28414859]),
#  array([2288.24981325]),
#  array([2003.60884199]),
#  array([1818.21387867]),
#  array([2777.75309521]),
#  array([2814.86469697]),
#  array([3304.35875213]),
#  array([1737.81954041]),
#  array([1846.9462498]),
#  array([1844.11633114]),
#  array([1739.5544895]),
#  array([2258.56648148]),
#  array([2304.42762883]),
#  array([2227.70828185]),
#  array([2188.42309084]),
#  array([2449.68131427]),
#  array([2021.63045201]),
#  array([2229.58921537]),
#  array([12266.60796515]),
#  array([4743.58595928]),
#  array([811.72570308]),
#  array([242.4002999]),
#  array([221.08050271]),
#  array([267.73873082]),
#  array([267.98370852]),
#  array([400.85012534]),
#  array([303.3938164]),
#  array([257.88578119]),
#  array([154.15398628]),
#  array([277.19652649]),
#  array([431.50143416]),
#  array([461.88619165]),
#  array([479.77498174]),
#  array([243.1524383]),
#  array([209.40204355]),
#  array([841.49784741]),
#  array([1900.72837375]),
#  array([19414.84762449]),
#  array([2716.05458377]),
#  array([2601.3543189]),
#  array([1972.23850995]),
#  array([2433.81923604]),
#  array([2543.55888322]),
#  array([3117.98998388]),
#  array([2279.48626899]),
#  array([12596.54246412]),
#  array([12054.06543521]),
#  array([2086.78895007]),
#  array([1820.27430923]),
#  array([1879.71116672]),
#  array([1813.36435548]),
#  array([3510.40865323]),
#  array([1824.0115016]),
#  array([4607.70814327]),
#  array([7187.4431143]),
#  array([3099.99104161]),
#  array([1989.90662612]),
#  array([1842.3350597]),
#  array([1981.05573433]),
#  array([1929.79631973]),
#  array([1790.13720154]),
#  array([6470.04711324]),
#  array([1886.25848949]),
#  array([7365.40872748]),
#  array([13000.16221765]),
#  array([2217.61648032]),
#  array([2241.88705199]),
#  array([1900.73795411]),
#  array([2320.85608576]),
#  array([2006.55065654]),
#  array([1840.8688528]),
#  array([2847.28759058]),
#  array([1898.11400645]),
#  array([1850.83707264]),
#  array([1909.62773293]),
#  array([1867.14496368]),
#  array([5822.83839952]),
#  array([17950.84925117]),
#  array([10520.62514926]),
#  array([9504.40928055]),
#  array([432.05614534]),
#  array([580.03351024]),
#  array([624.28637961]),
#  array([1540.01766655]),
#  array([840.59776956]),
#  array([1014.28391175]),
#  array([1989.4631581]),
#  array([179.83902756]),
#  array([573.61695321]),
#  array([1711.55522862]),
#  array([18845.56427762]),
#  array([4349.67823543]),
#  array([2813.31234844]),
#  array([14572.90117685]),
#  array([2368.10780952]),
#  array([2264.1724715]),
#  array([2135.02516805]),
#  array([2023.47127813]),
#  array([2010.62068446]),
#  array([3932.92197598]),
#  array([1917.1195264]),
#  array([1976.54604245]),
#  array([1979.34502546]),
#  array([1809.76715493]),
#  array([2079.5512462]),
#  array([2002.73399064]),
#  array([2068.58778036]),
#  array([4466.75633548]),
#  array([3651.17432043]),
#  array([2431.07896303]),
#  array([8213.44175546]),
#  array([1924.37578255]),
#  array([1790.65013359]),
#  array([1807.48398906]),
#  array([2247.87870987]),
#  array([1797.45270219]),
#  array([1900.61907189]),
#  array([1877.80982817]),
#  array([1979.80538983]),
#  array([1969.04334522]),
#  array([2303.2508618]),
#  array([21757.6007426]),
#  array([4807.66414891]),
#  array([8822.68674908]),
#  array([15446.05999411]),
#  array([628.08753118]),
#  array([427.66533604]),
#  array([427.65533043]),
#  array([381.57184228]),
#  array([2999.47759413]),
#  array([2723.20546604]),
#  array([2177.23057445]),
#  array([143.60622148]),
#  array([125.39197733]),
#  array([490.32173685]),
#  array([405.63849352]),
#  array([197.52369312]),
#  ...]

# %%
k = np.sqrt(dff.shape[0])
k = int(np.ceil(k))
k
# Out:
# 37

# %%
df.tail()
# Out:
#         Cyclone_Inlet_Gas_Temp  Cyclone_Material_Temp  \
# 377714                  899.42                 919.79
# 377715                  879.90                 895.02
# 377716                  887.20                 895.70
# 377717                  908.50                 916.33
# 377718                  880.86                 905.31
#
#         Cyclone_Outlet_Gas_draft  Cyclone_cone_draft  Cyclone_Gas_Outlet_Temp  \
# 377714                   -224.07             -209.77                   901.01
# 377715                   -228.04             -211.28                   878.08
# 377716                   -230.11             -214.65                   885.32
# 377717                   -231.51             -218.09                   906.20
# 377718                   -235.02             -219.44                   882.10
#
#         Cyclone_Inlet_Draft       date timestamp
# 377714              -175.15 2020-08-07  11:55:00
# 377715              -176.94 2020-08-07  12:00:00
# 377716              -179.18 2020-08-07  12:05:00
# 377717              -181.96 2020-08-07  12:10:00
# 377718              -184.02 2020-08-07  12:15:00

# %%
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2020, 8, 7)
index = pd.date_range(start, end)
index
dfrad = pd.DataFrame(index, columns = ["date"])
dfrad

rad = pd.DataFrame(radius)

rad["yhat"]=(k/((math.pi)*(rad.iloc[:]**2)))

rad["probability"]=1-(rad["yhat"]/max(rad["yhat"]))

rad['Date'] = dfrad['date']


rad[['Date',"probability"]].head(50)
# Out:
#          Date  probability
# 0  2017-01-01     0.996179
# 1  2017-01-02     0.995476
# 2  2017-01-03     0.995333
# 3  2017-01-04     0.998579
# 4  2017-01-05     0.996267
# 5  2017-01-06     0.998050
# 6  2017-01-07     0.997979
# 7  2017-01-08     0.998714
# 8  2017-01-09     0.997110
# 9  2017-01-10     0.997193
# 10 2017-01-11     0.996382
# 11 2017-01-12     0.996031
# 12 2017-01-13     0.996552
# 13 2017-01-14     0.995843
# 14 2017-01-15     0.995867
# 15 2017-01-16     0.997833
# 16 2017-01-17     0.997627
# 17 2017-01-18     0.996568
# 18 2017-01-19     0.999145
# 19 2017-01-20     0.998402
# 20 2017-01-21     0.995098
# 21 2017-01-22     0.999393
# 22 2017-01-23     0.999974
# 23 2017-01-24     0.995522
# 24 2017-01-25     0.999890
# 25 2017-01-26     0.999934
# 26 2017-01-27     0.996880
# 27 2017-01-28     0.999509
# 28 2017-01-29     0.996066
# 29 2017-01-30     0.996021
# 30 2017-01-31     0.996501
# 31 2017-02-01     0.999421
# 32 2017-02-02     0.997382
# 33 2017-02-03     0.997201
# 34 2017-02-04     0.995606
# 35 2017-02-05     0.996216
# 36 2017-02-06     0.996248
# 37 2017-02-07     0.995977
# 38 2017-02-08     0.999440
# 39 2017-02-09     0.998084
# 40 2017-02-10     0.996747
# 41 2017-02-11     0.998013
# 42 2017-02-12     0.998039
# 43 2017-02-13     0.997444
# 44 2017-02-14     0.997458
# 45 2017-02-15     0.994944
# 46 2017-02-16     0.997780
# 47 2017-02-17     0.997080
# 48 2017-02-18     0.997493
# 49 2017-02-19     0.997350

# %%
result_outlier = rad[rad['probability'] > 0.999]
result_outlier
# Out:
#                  0          yhat  probability       Date
# 18     3441.454731  9.944151e-07     0.999145 2017-01-19
# 21     4085.342397  7.056591e-07     0.999393 2017-01-22
# 22    19882.347877  2.979316e-08     0.999974 2017-01-23
# 24     9610.218869  1.275221e-07     0.999890 2017-01-25
# 25    12395.642757  7.665028e-08     0.999934 2017-01-26
# ...            ...           ...          ...        ...
# 1293   5446.057118  3.970886e-07     0.999659 2020-07-17
# 1294   7583.035538  2.048168e-07     0.999824 2020-07-18
# 1299  16465.905550  4.343908e-08     0.999963 2020-07-23
# 1300   3489.773324  9.670689e-07     0.999168 2020-07-24
# 1303  11799.103576  8.459678e-08     0.999927 2020-07-27
#
# [373 rows x 4 columns]

# %%
result_not_ouliers = rad[rad['probability'] < 0.999]

# %%
model = MDS(n_components=2, dissimilarity='precomputed', random_state=1)
mds_out = model.fit_transform(dist)
dates = df['date'].dt.date.values
x = mds_out[:,0]
y = mds_out[:,1]

plt.figure(figsize=(15,10))
plt.scatter(x,y)
# for i, txt in enumerate(dates):
#     try:
#         plt.annotate(txt, (x[i]+0.3, y[i]+0.3))
#     except:
#         continue
plt.title("year")
plt.show()

# %%
mds_out.shape
# Out:
# (1311, 2)

# %%
mds_out
# Out:
# array([[  1111.01147586,  -1283.4685868 ],
#        [   180.8420596 ,  -2903.82057982],
#        [   270.77292504,  -2543.43350738],
#        ...,
#        [ -8353.3813361 , -13824.9640559 ],
#        [ -7563.64504738, -13542.45145362],
#        [ -8220.5177628 , -12811.81003692]])

# %%
x.shape[0]
# Out:
# 1311

# %%
# x1  = mds_out[result_less.index.values,0]
# print(x1.shape[0])
# # y = mds_out[~result_rad.index.values,1] 
# # plt.scatter(x, y)
# # plt.show()

# %%
x_less = mds_out[result_not_ouliers.index.values,0]
y_less = mds_out[result_not_ouliers.index.values,1]

plt.scatter(x_less,y_less,c="red")
plt.show()

# %%
x_outlier = mds_out[result_outlier.index.values,0]
y_outlier = mds_out[result_outlier.index.values,1]

plt.scatter(x_outlier,y_outlier,c="black")
plt.show()

# %%
df_outlier_r = result_outlier.sample(n=5)

# %%
df_outlier_r
# Out:
#                  0          yhat  probability       Date
# 414    8752.313075  1.537468e-07     0.999868 2018-02-19
# 1138   3609.387643  9.040341e-07     0.999223 2020-02-13
# 411   19712.901663  3.030754e-08     0.999974 2018-02-16
# 987   15446.059994  4.936469e-08     0.999958 2019-09-15
# 93     5611.659432  3.739980e-07     0.999678 2017-04-04

# %%
df
# Out:
#         Cyclone_Inlet_Gas_Temp  Cyclone_Material_Temp  \
# 0                       867.63                 910.42
# 1                       879.23                 918.14
# 2                       875.67                 924.18
# 3                       875.28                 923.15
# 4                       891.66                 934.26
# ...                        ...                    ...
# 377714                  899.42                 919.79
# 377715                  879.90                 895.02
# 377716                  887.20                 895.70
# 377717                  908.50                 916.33
# 377718                  880.86                 905.31
#
#         Cyclone_Outlet_Gas_draft  Cyclone_cone_draft  Cyclone_Gas_Outlet_Temp  \
# 0                        -189.54             -186.04                   852.13
# 1                        -184.33             -182.10                   862.53
# 2                        -181.26             -166.47                   866.06
# 3                        -179.15             -174.83                   865.85
# 4                        -178.32             -173.72                   876.06
# ...                          ...                 ...                      ...
# 377714                   -224.07             -209.77                   901.01
# 377715                   -228.04             -211.28                   878.08
# 377716                   -230.11             -214.65                   885.32
# 377717                   -231.51             -218.09                   906.20
# 377718                   -235.02             -219.44                   882.10
#
#         Cyclone_Inlet_Draft       date timestamp
# 0                   -145.90 2017-01-01  00:00:00
# 1                   -149.76 2017-01-01  00:05:00
# 2                   -145.01 2017-01-01  00:10:00
# 3                   -142.82 2017-01-01  00:15:00
# 4                   -143.39 2017-01-01  00:20:00
# ...                     ...        ...       ...
# 377714              -175.15 2020-08-07  11:55:00
# 377715              -176.94 2020-08-07  12:00:00
# 377716              -179.18 2020-08-07  12:05:00
# 377717              -181.96 2020-08-07  12:10:00
# 377718              -184.02 2020-08-07  12:15:00
#
# [377719 rows x 8 columns]

# %%
# from sklearn.cluster import KMeans

# kmeans = KMeans(n_clusters=3, random_state=0).fit(mds_out)

# %%
## Calculate FFT of each sample, followed by absolute value
## of Foruier coefficients and a pairwise distance between
## samples
fftval_cyc = df.groupby("date").apply(lambda x:  fft(x['Cyclone_Material_Temp'].values))
#fftval = fftval[:-1].to_numpy()
fftval_cyc = np.array([x for x in fftval_cyc.values if len(x) == 288])
fftmag_cyc = np.abs(fftval_cyc)
dist_cyc = squareform(pdist(np.abs(fftmag_cyc), 'euclidean'))

# %%
dff_cyc = pd.DataFrame(dist_cyc)
dff_cyc
# Out:
#               0             1             2             3             4     \
# 0         0.000000   3212.028520   2967.028059   3106.518369   3785.403625
# 1      3212.028520      0.000000   4970.790775   5336.194615   5940.239079
# 2      2967.028059   4970.790775      0.000000   2632.705807   3770.263930
# 3      3106.518369   5336.194615   2632.705807      0.000000   3077.158516
# 4      3785.403625   5940.239079   3770.263930   3077.158516      0.000000
# ...            ...           ...           ...           ...           ...
# 1306   9119.006975  11021.961818   7772.514965   7134.624221   8252.308500
# 1307  12886.494854  15167.991014  10883.625579  10680.542390  11162.654694
# 1308   9042.679001  11280.676827   7032.117423   6985.274015   7868.833051
# 1309   8171.518547  10474.714349   6514.257625   6194.869876   6744.831466
# 1310   8038.414583  10285.979479   6162.419346   5934.538660   6643.837219
#
#               5            6             7             8            9     ...  \
# 0      4762.378708  4704.722555   8109.173802   8570.465370  7005.070669  ...
# 1      3120.378298  6689.439005  10315.489084  10863.659883  8967.575483  ...
# 2      7027.824429  3036.822637   6004.358816   6614.820710  6087.197292  ...
# 3      6995.555790  3576.496164   6105.176965   6343.061491  5543.051442  ...
# 4      7269.141985  5281.367677   7323.577395   6702.435793  5075.916750  ...
# ...            ...          ...           ...           ...          ...  ...
# 1306  12370.771569  6569.961775   5490.981111   5845.777175  6966.671438  ...
# 1307  16888.585735  9766.524618   6651.525344   6318.239190  8461.319979  ...
# 1308  13224.879723  6044.260921   3764.033104   4173.223147  6447.326412  ...
# 1309  12056.666110  6074.196722   4680.318236   4261.370654  5514.413274  ...
# 1310  12054.104698  5369.596948   3987.674083   3629.138041  5350.844180  ...
#
#               1301          1302          1303          1304          1305  \
# 0     28728.213900  11238.431749  18013.972785  12930.255624  12425.064400
# 1     29835.464252  13486.145730  19685.655993  15127.534212  14677.214583
# 2     28382.315736   9311.918091  17336.135918  10880.481168  10385.396798
# 3     27406.984043   9028.461727  16262.897170  10935.995776  10254.496678
# 4     26787.790504   9803.512269  15598.310367  11739.509914  11219.932760
# ...            ...           ...           ...           ...           ...
# 1306  25781.358574   6382.336138  14867.448146   7578.950788   7335.088207
# 1307  26316.497355   4662.960625  14564.480036   4544.934206   4202.366173
# 1308  25934.433473   5071.433665  14445.935919   6112.911519   5774.312109
# 1309  25667.382047   5508.732097  14362.101374   6815.594857   6400.766680
# 1310  26362.306133   5205.933063  14994.769418   6705.042094   5949.834291
#
#               1306          1307          1308          1309          1310
# 0      9119.006975  12886.494854   9042.679001   8171.518547   8038.414583
# 1     11021.961818  15167.991014  11280.676827  10474.714349  10285.979479
# 2      7772.514965  10883.625579   7032.117423   6514.257625   6162.419346
# 3      7134.624221  10680.542390   6985.274015   6194.869876   5934.538660
# 4      8252.308500  11162.654694   7868.833051   6744.831466   6643.837219
# ...            ...           ...           ...           ...           ...
# 1306      0.000000   7379.399520   5552.917017   5015.676033   4918.495718
# 1307   7379.399520      0.000000   5763.271519   6458.931223   5975.152126
# 1308   5552.917017   5763.271519      0.000000   4138.546858   3854.880137
# 1309   5015.676033   6458.931223   4138.546858      0.000000   3415.559168
# 1310   4918.495718   5975.152126   3854.880137   3415.559168      0.000000
#
# [1311 rows x 1311 columns]

# %%
radius_cyc=[]
for i in range(len(dff_cyc)):
    x_cyc=dff.sort_values(by=i, axis = 1).iloc[i:i+1,1:37]
    radius_cyc.append(x_cyc.iloc[:, -1].values)
radius_cyc
# Out:
# [array([2910.13150033]),
#  array([3408.50905462]),
#  array([2896.58918905]),
#  array([3536.1833002]),
#  array([3454.6918573]),
#  array([4091.12626967]),
#  array([3895.26869432]),
#  array([3979.64436115]),
#  array([3429.53868061]),
#  array([3488.50752599]),
#  array([2924.5260495]),
#  array([3433.41472056]),
#  array([3386.05610415]),
#  array([3260.20521732]),
#  array([3572.31534868]),
#  array([3429.12902998]),
#  array([3358.22424234]),
#  array([3716.2474825]),
#  array([3737.28669633]),
#  array([3479.41248018]),
#  array([3968.46819751]),
#  array([4648.13882006]),
#  array([25392.55499309]),
#  array([3770.94428513]),
#  array([7549.9213246]),
#  array([6780.4840625]),
#  array([4051.0868142]),
#  array([4312.44551788]),
#  array([2777.48175983]),
#  array([2944.11141787]),
#  array([4793.95481265]),
#  array([4286.12947777]),
#  array([3004.94493998]),
#  array([3352.21593129]),
#  array([2579.58964479]),
#  array([3714.59729567]),
#  array([2947.16420893]),
#  array([2905.57887948]),
#  array([4687.51594651]),
#  array([3119.29234035]),
#  array([3579.968715]),
#  array([3160.07322023]),
#  array([3773.41960295]),
#  array([3081.53237786]),
#  array([3821.97407829]),
#  array([3269.17923154]),
#  array([3365.12270068]),
#  array([2944.65071715]),
#  array([3112.16457408]),
#  array([3086.73802591]),
#  array([3482.14078411]),
#  array([3210.09981678]),
#  array([3348.86547052]),
#  array([2780.35383809]),
#  array([2895.15825175]),
#  array([4341.32649921]),
#  array([3233.1120572]),
#  array([3561.08991084]),
#  array([3981.82008294]),
#  array([3257.17461473]),
#  array([18746.4168978]),
#  array([3025.5614766]),
#  array([3002.79780557]),
#  array([2753.92986843]),
#  array([2928.88522855]),
#  array([6739.12181168]),
#  array([4302.3098562]),
#  array([2654.38213619]),
#  array([2736.53951885]),
#  array([2720.38060162]),
#  array([4270.77291674]),
#  array([3011.0511388]),
#  array([4021.39310809]),
#  array([3130.17133652]),
#  array([4692.34124885]),
#  array([3035.42390379]),
#  array([3546.63967659]),
#  array([3463.11887669]),
#  array([4516.72180832]),
#  array([57495.76428432]),
#  array([33560.66201816]),
#  array([59236.00880194]),
#  array([39920.92135364]),
#  array([26829.21792267]),
#  array([4952.03564048]),
#  array([3820.73540433]),
#  array([2639.54245309]),
#  array([4049.04377097]),
#  array([9851.10291511]),
#  array([4393.70682014]),
#  array([3140.24336067]),
#  array([4259.96015875]),
#  array([5065.28823418]),
#  array([4261.22453004]),
#  array([56843.47722346]),
#  array([51797.6752894]),
#  array([11747.17965851]),
#  array([3317.13781563]),
#  array([4055.21698567]),
#  array([2863.91925528]),
#  array([3332.0326867]),
#  array([4011.74416674]),
#  array([3534.02775544]),
#  array([4464.92945433]),
#  array([3424.83972412]),
#  array([3511.26753356]),
#  array([5813.03198742]),
#  array([5116.2891194]),
#  array([8055.63407549]),
#  array([8127.80402636]),
#  array([4861.26280188]),
#  array([3951.1575491]),
#  array([4292.4667101]),
#  array([4075.32424857]),
#  array([3497.18909358]),
#  array([3572.9160623]),
#  array([3327.84036695]),
#  array([3801.04729328]),
#  array([4328.83084382]),
#  array([3086.73802591]),
#  array([4558.8621312]),
#  array([2838.02911359]),
#  array([3505.77071446]),
#  array([3459.50046108]),
#  array([3374.55436989]),
#  array([4545.93045793]),
#  array([3208.20426345]),
#  array([2806.30620984]),
#  array([4026.10444752]),
#  array([3222.73001809]),
#  array([3295.8345199]),
#  array([3893.9335085]),
#  array([3713.90611583]),
#  array([3499.14081366]),
#  array([3718.84096121]),
#  array([2979.1196795]),
#  array([3286.16653527]),
#  array([3837.49960117]),
#  array([61609.20532981]),
#  array([6318.2002827]),
#  array([2837.06634797]),
#  array([589.99017083]),
#  array([689.82782716]),
#  array([997.26501302]),
#  array([835.55103499]),
#  array([992.98879009]),
#  array([1200.06201966]),
#  array([1233.26515607]),
#  array([6800.68021281]),
#  array([61421.33101918]),
#  array([12868.44563232]),
#  array([7848.03862617]),
#  array([3771.12161008]),
#  array([5926.19063737]),
#  array([5874.71413113]),
#  array([5247.266096]),
#  array([5125.87575091]),
#  array([3636.19172447]),
#  array([25702.98086939]),
#  array([19860.48430384]),
#  array([4105.81356949]),
#  array([4238.41870715]),
#  array([8729.4537975]),
#  array([2988.93109398]),
#  array([15497.02250273]),
#  array([3846.32853977]),
#  array([7049.52972463]),
#  array([3485.53088902]),
#  array([3246.96228612]),
#  array([3028.55863972]),
#  array([3270.60853321]),
#  array([3262.87667181]),
#  array([5809.39308503]),
#  array([3422.11632756]),
#  array([4765.902803]),
#  array([4718.84374498]),
#  array([5744.23539095]),
#  array([4241.9207623]),
#  array([4747.98844915]),
#  array([4224.44130959]),
#  array([4705.69813047]),
#  array([2899.07645622]),
#  array([4168.48591998]),
#  array([4975.43620885]),
#  array([3589.69692624]),
#  array([3722.88489391]),
#  array([3679.52638462]),
#  array([4004.48215945]),
#  array([2916.01018282]),
#  array([2562.29514907]),
#  array([2619.74351945]),
#  array([4454.33299046]),
#  array([3175.62147267]),
#  array([3082.76144346]),
#  array([2710.83945976]),
#  array([3011.49242963]),
#  array([3226.55461763]),
#  array([3028.19498273]),
#  array([3256.99530513]),
#  array([3011.96280624]),
#  array([14028.77053069]),
#  array([2691.13081895]),
#  array([3145.97386344]),
#  array([2615.23531801]),
#  array([2666.13619]),
#  array([2585.94117481]),
#  array([2921.58887258]),
#  array([3161.80702006]),
#  array([5017.12762321]),
#  array([4594.21461046]),
#  array([3606.90830716]),
#  array([45158.39474081]),
#  array([3722.82615795]),
#  array([4201.73124349]),
#  array([3166.51552421]),
#  array([3455.69597112]),
#  array([6949.3934499]),
#  array([4223.79041038]),
#  array([3595.42944468]),
#  array([3430.34326972]),
#  array([4301.77288457]),
#  array([3575.35280393]),
#  array([2913.55470558]),
#  array([2635.74249734]),
#  array([2707.0363684]),
#  array([3930.9157056]),
#  array([3545.15695615]),
#  array([4827.7148878]),
#  array([4525.30322895]),
#  array([4560.46566893]),
#  array([5068.6990991]),
#  array([4523.56358219]),
#  array([3932.67956002]),
#  array([3975.27528812]),
#  array([4160.62401246]),
#  array([4293.74154941]),
#  array([4264.26864755]),
#  array([3642.98804341]),
#  array([3890.84471019]),
#  array([4303.97256468]),
#  array([3320.95407638]),
#  array([2666.70154869]),
#  array([3554.0866622]),
#  array([4713.5248352]),
#  array([3372.08198877]),
#  array([4576.4321846]),
#  array([4157.89570645]),
#  array([4001.15635604]),
#  array([4946.742523]),
#  array([5885.1423422]),
#  array([4609.19087605]),
#  array([25884.82092202]),
#  array([5134.7349218]),
#  array([5174.05632327]),
#  array([13776.23377264]),
#  array([56452.50116905]),
#  array([12890.17977115]),
#  array([3819.69493609]),
#  array([4331.07097]),
#  array([10106.61678657]),
#  array([5379.9286817]),
#  array([58706.37272639]),
#  array([9178.53762107]),
#  array([1961.42140664]),
#  array([711.61188351]),
#  array([342.53358611]),
#  array([336.45225333]),
#  array([326.03331638]),
#  array([342.74961912]),
#  array([444.39828537]),
#  array([424.71763098]),
#  array([443.77539612]),
#  array([390.06371549]),
#  array([413.87093164]),
#  array([418.38471622]),
#  array([308.91357206]),
#  array([351.71903726]),
#  array([432.2333633]),
#  array([373.52649693]),
#  array([505.75866697]),
#  array([511.29522563]),
#  array([473.6675088]),
#  array([440.73774882]),
#  array([59660.95627212]),
#  array([4181.43957901]),
#  array([410.31769544]),
#  array([411.19933763]),
#  array([392.84423726]),
#  array([353.48501705]),
#  array([5857.57757685]),
#  array([51432.23372474]),
#  array([24685.33753772]),
#  array([13453.44208595]),
#  array([8685.48401279]),
#  array([4024.169678]),
#  array([7024.3609127]),
#  array([4948.94663976]),
#  array([4792.57942003]),
#  array([4861.32530353]),
#  array([24769.45564907]),
#  array([6095.18192649]),
#  array([3762.22633057]),
#  array([3874.63538466]),
#  array([10220.6268213]),
#  array([4773.24997796]),
#  array([3881.57011621]),
#  array([3562.57914492]),
#  array([4181.57870565]),
#  array([3398.74206745]),
#  array([3891.52402657]),
#  array([4237.47435324]),
#  array([4028.84556356]),
#  array([4245.13059179]),
#  array([5190.59326711]),
#  array([4670.79986886]),
#  array([4312.93339239]),
#  array([4060.01790148]),
#  array([4218.96970234]),
#  array([3322.75103527]),
#  array([4940.05439664]),
#  array([4478.45685751]),
#  array([4458.23714653]),
#  array([5815.24384426]),
#  array([3625.98994775]),
#  array([3838.07925931]),
#  array([4833.35547177]),
#  array([4626.65217005]),
#  array([4443.33270036]),
#  array([5266.84100291]),
#  array([4588.10240845]),
#  array([13072.95679779]),
#  array([59000.64770612]),
#  array([1165.84206534]),
#  array([444.73425308]),
#  array([349.33898072]),
#  array([614.73945126]),
#  array([925.33747476]),
#  array([1131.17212881]),
#  array([9033.43275626]),
#  array([992.90440497]),
#  array([33428.91219203]),
#  array([59758.59919604]),
#  array([8589.97880233]),
#  array([4131.74207161]),
#  array([3988.72395564]),
#  array([9233.97510371]),
#  array([4896.92039461]),
#  array([3654.45028348]),
#  array([4099.08881852]),
#  array([5064.45634304]),
#  array([4927.08560291]),
#  array([3385.05645195]),
#  array([3599.91102802]),
#  array([4511.28209886]),
#  array([3349.19558438]),
#  array([3289.01895687]),
#  array([3244.91168606]),
#  array([3549.95364859]),
#  array([10006.8562291]),
#  array([4221.82502451]),
#  array([7360.74185594]),
#  array([5369.19246715]),
#  array([5101.13818894]),
#  array([5096.86997691]),
#  array([7168.28140716]),
#  array([5028.59960822]),
#  array([5570.86700891]),
#  array([4861.41294899]),
#  array([4183.08369858]),
#  array([4340.27755639]),
#  array([4615.20492583]),
#  array([6399.57971063]),
#  array([5396.39051241]),
#  array([5977.39584583]),
#  array([4942.21370262]),
#  array([3411.27434594]),
#  array([3747.66425067]),
#  array([3954.27644858]),
#  array([3925.872281]),
#  array([16085.42539387]),
#  array([4584.87025365]),
#  array([4540.2766273]),
#  array([5573.07917453]),
#  array([4888.23047152]),
#  array([4551.28182016]),
#  array([3338.22056002]),
#  array([4436.93271233]),
#  array([3031.63275457]),
#  array([4625.16360021]),
#  array([3916.1224389]),
#  array([3426.68571905]),
#  array([4027.81495386]),
#  array([4296.58173939]),
#  array([5160.8601984]),
#  array([4802.26579931]),
#  array([47133.2226379]),
#  array([62237.41667403]),
#  array([4035.01677371]),
#  array([4327.23828986]),
#  array([4195.28554738]),
#  array([4280.8806532]),
#  array([3627.0435446]),
#  array([4869.12241098]),
#  array([3304.28281686]),
#  array([3603.42266537]),
#  array([18483.10299648]),
#  array([4640.35775579]),
#  array([3839.24944912]),
#  array([4273.84212745]),
#  array([14327.18811294]),
#  array([52076.72178304]),
#  array([64635.55234599]),
#  array([4149.52803511]),
#  array([15797.04123964]),
#  array([4531.28134559]),
#  array([4619.78662231]),
#  array([6568.71272855]),
#  array([6976.1560072]),
#  array([26553.0751488]),
#  array([2900.62412788]),
#  array([32636.86439046]),
#  array([4184.41406981]),
#  array([5925.53875053]),
#  array([5929.40384371]),
#  array([4770.60343785]),
#  array([3538.97903636]),
#  array([4362.64301578]),
#  array([3132.93538117]),
#  array([4058.44341069]),
#  array([7274.76585866]),
#  array([7999.66627196]),
#  array([3404.02101217]),
#  array([4792.46446856]),
#  array([4087.72179648]),
#  array([5210.0557438]),
#  array([5406.08825874]),
#  array([3983.64586491]),
#  array([3870.30724978]),
#  array([5168.76509252]),
#  array([4678.79113975]),
#  array([3575.3792414]),
#  array([4446.34612995]),
#  array([6159.32118929]),
#  array([5647.4051411]),
#  array([4718.00275136]),
#  array([4229.95770777]),
#  array([3960.41047707]),
#  array([4574.6532526]),
#  array([4507.77953951]),
#  array([5446.5667892]),
#  array([4573.36942723]),
#  array([3755.70461408]),
#  array([5451.52079529]),
#  array([4530.67358994]),
#  array([33204.38324959]),
#  array([53084.08026191]),
#  array([31393.5946787]),
#  array([22180.55626852]),
#  array([4699.94191159]),
#  array([4893.95559068]),
#  array([3487.22066248]),
#  array([5668.72793262]),
#  array([3620.76314315]),
#  array([4068.52800986]),
#  array([3975.72245538]),
#  array([3440.23302123]),
#  array([3977.16582894]),
#  array([8629.85287748]),
#  array([3479.23457651]),
#  array([4751.07819548]),
#  array([4359.29003266]),
#  array([4563.91097348]),
#  array([5022.01311296]),
#  array([3821.22291094]),
#  array([4606.59172751]),
#  array([4680.94361225]),
#  array([4316.72703284]),
#  array([4827.79751592]),
#  array([4370.87465052]),
#  array([3301.59384623]),
#  array([5103.19860716]),
#  array([6462.57490135]),
#  array([60199.28713793]),
#  array([12118.59590537]),
#  array([60199.28713793]),
#  array([7683.74430223]),
#  array([18497.91508124]),
#  array([4814.24127478]),
#  array([3683.45432696]),
#  array([3034.10687081]),
#  array([6955.42122683]),
#  array([8780.38687419]),
#  array([12690.99793155]),
#  array([5214.461107]),
#  array([3733.79021217]),
#  array([3861.34684363]),
#  array([5095.52343266]),
#  array([5153.52523727]),
#  array([4303.09085854]),
#  array([28689.06558432]),
#  array([5801.93670421]),
#  array([4770.04176749]),
#  array([5653.54337744]),
#  array([4384.89861315]),
#  array([3952.66035301]),
#  array([5276.30662034]),
#  array([7437.99583595]),
#  array([5573.08688455]),
#  array([5757.17906768]),
#  array([6188.6806037]),
#  array([5367.11505973]),
#  array([5493.99899988]),
#  array([7246.91511724]),
#  array([5539.90865132]),
#  array([22037.72473493]),
#  array([20228.90186994]),
#  array([6437.2862336]),
#  array([4615.17505976]),
#  array([5513.97427274]),
#  array([70307.71827423]),
#  array([54716.83668154]),
#  array([37788.85037694]),
#  array([4958.28208945]),
#  array([5078.74349437]),
#  array([6407.91361745]),
#  array([4654.45595793]),
#  array([5755.588682]),
#  array([4110.45061357]),
#  array([4902.84384921]),
#  array([4953.49445687]),
#  array([5027.69781748]),
#  array([4724.68056752]),
#  array([8753.50667625]),
#  array([12886.62658724]),
#  array([57533.07020297]),
#  array([61864.59421378]),
#  array([4934.4372809]),
#  array([6965.45343707]),
#  array([4123.34080293]),
#  array([4625.98160777]),
#  array([5452.09909369]),
#  array([10742.09929511]),
#  array([20506.52715146]),
#  array([3802.43106174]),
#  array([5442.19578771]),
#  array([4942.44821508]),
#  array([7699.6553676]),
#  array([6133.49978354]),
#  array([16694.72853109]),
#  array([50749.20755993]),
#  array([3004.60391049]),
#  array([783.83926817]),
#  array([36519.04343619]),
#  array([64654.05588034]),
#  array([64677.03331897]),
#  array([5200.16620867]),
#  array([3465.5578401]),
#  array([7974.19764722]),
#  array([6610.63350039]),
#  array([50927.77233848]),
#  array([6969.38953814]),
#  array([4335.23598382]),
#  array([4278.37576232]),
#  array([6836.66441751]),
#  array([5755.30098795]),
#  array([9888.80642707]),
#  array([7921.59582078]),
#  array([6729.83178873]),
#  array([6450.69276667]),
#  array([7411.25269718]),
#  array([6072.93084237]),
#  array([4168.48265745]),
#  array([5163.40460089]),
#  array([4631.14498231]),
#  array([9688.63935195]),
#  array([6152.6403631]),
#  array([5694.22525161]),
#  array([6655.65950939]),
#  array([4984.04805937]),
#  array([5701.73996119]),
#  array([6863.3270773]),
#  array([4868.6697654]),
#  array([5502.42972386]),
#  array([5024.04526053]),
#  array([5237.12447847]),
#  array([3920.37976037]),
#  array([4033.67439011]),
#  array([4433.60704988]),
#  array([5712.18942039]),
#  array([5096.34010982]),
#  array([3878.37772841]),
#  array([4948.79535286]),
#  array([4000.07866264]),
#  array([4596.93241629]),
#  array([4144.67125858]),
#  array([5283.82443826]),
#  array([6535.0241527]),
#  array([7474.06916913]),
#  array([6265.6547915]),
#  array([5059.96174318]),
#  array([5939.16529369]),
#  array([5123.42231308]),
#  array([4450.44741599]),
#  array([5145.93423195]),
#  array([61767.42701294]),
#  array([3887.14049777]),
#  array([352.68601342]),
#  array([3671.81538942]),
#  array([57636.08393943]),
#  array([7823.66383207]),
#  array([4736.52265309]),
#  array([3977.80879052]),
#  array([4874.61088643]),
#  array([5396.19205404]),
#  array([5267.95360765]),
#  array([5164.91941007]),
#  array([4163.25828518]),
#  array([5380.84362508]),
#  array([5284.49311606]),
#  array([4839.62142285]),
#  array([6702.28562007]),
#  array([71703.393033]),
#  array([8734.56655833]),
#  array([71536.30408025]),
#  array([8403.51905819]),
#  array([12504.87103245]),
#  array([4285.89308694]),
#  array([6036.60058436]),
#  array([4517.54901863]),
#  array([5394.60490884]),
#  array([4320.8188512]),
#  array([41346.26015289]),
#  array([26996.61359057]),
#  array([3762.20890799]),
#  array([1086.57310101]),
#  array([605.44179534]),
#  array([491.41934175]),
#  array([463.66079174]),
#  array([470.42770159]),
#  array([394.0842898]),
#  array([395.60544106]),
#  array([443.59986022]),
#  array([399.48225161]),
#  array([324.76231873]),
#  array([335.86111548]),
#  array([337.44896357]),
#  array([322.76496012]),
#  array([328.64892652]),
#  array([406.78117534]),
#  array([364.09299862]),
#  array([321.10862682]),
#  array([365.83307494]),
#  array([26738.76173429]),
#  array([57407.89249251]),
#  array([48955.56100136]),
#  array([4748.49753334]),
#  array([4018.83630867]),
#  array([4136.25225659]),
#  array([4871.5010862]),
#  array([19624.02573664]),
#  array([4085.21388339]),
#  array([4903.24405729]),
#  array([19279.92704053]),
#  array([4324.94669333]),
#  array([4759.83329836]),
#  array([3215.09319017]),
#  array([2899.00009056]),
#  array([3066.51799812]),
#  array([4153.0325322]),
#  array([4682.1217589]),
#  array([4059.67960785]),
#  array([58038.49366303]),
#  array([65725.73445157]),
#  array([3481.64830664]),
#  array([3881.77846513]),
#  array([3753.29076861]),
#  array([4094.28849274]),
#  array([4180.15821595]),
#  array([4037.80657328]),
#  array([3841.59438252]),
#  array([6109.81065933]),
#  array([4623.27308931]),
#  array([4654.27887765]),
#  array([4693.49858966]),
#  array([6005.83229761]),
#  array([4204.26859219]),
#  array([4285.40730375]),
#  array([3981.88053528]),
#  array([5253.43096591]),
#  array([4697.68246936]),
#  array([5134.75422405]),
#  array([4729.86205163]),
#  array([4258.41780581]),
#  array([4555.50817737]),
#  array([49233.63332325]),
#  array([59012.55853503]),
#  array([51739.30110075]),
#  array([34702.5404209]),
#  array([4752.40112492]),
#  array([4016.62051261]),
#  array([3397.30261163]),
#  array([3093.34145215]),
#  array([5829.29819776]),
#  array([69548.89666613]),
#  array([35948.02716003]),
#  array([5174.98678518]),
#  array([28635.81624508]),
#  array([7951.11683545]),
#  array([5502.46018234]),
#  array([3998.42281929]),
#  array([14344.03524294]),
#  array([4580.85703799]),
#  array([3087.2263112]),
#  array([2711.9118894]),
#  array([3011.28581637]),
#  array([2745.3088336]),
#  array([3390.06120752]),
#  array([3379.83541043]),
#  array([3935.88346899]),
#  array([6853.78521447]),
#  array([2981.55271978]),
#  array([3188.50859214]),
#  array([2748.77275555]),
#  array([3041.17509997]),
#  array([3670.67450047]),
#  array([3336.53451762]),
#  array([4595.60562656]),
#  array([3756.04198731]),
#  array([4319.47466474]),
#  array([2937.05537238]),
#  array([17336.36297501]),
#  array([3288.23200248]),
#  array([3420.38449274]),
#  array([3936.16452394]),
#  array([2836.48390356]),
#  array([4236.51625137]),
#  array([2605.33975817]),
#  array([3196.76718136]),
#  array([2969.79286301]),
#  array([8975.9152969]),
#  array([4127.42365948]),
#  array([5364.00129338]),
#  array([3306.87676254]),
#  array([2867.14245572]),
#  array([2867.66381602]),
#  array([6387.08867865]),
#  array([4864.27351076]),
#  array([4116.27451197]),
#  array([4099.70679822]),
#  array([3706.36676762]),
#  array([5579.59609653]),
#  array([4101.90067423]),
#  array([4879.17922718]),
#  array([4472.67604271]),
#  array([4014.37112114]),
#  array([4954.43202539]),
#  array([6108.16657089]),
#  array([4798.40303606]),
#  array([5182.67930574]),
#  array([9544.99942501]),
#  array([6681.20030682]),
#  array([2882.68240257]),
#  array([5305.58631931]),
#  array([4274.37536335]),
#  array([3229.51000875]),
#  array([3699.20987336]),
#  array([4298.75029784]),
#  array([3778.13063395]),
#  array([3259.64425616]),
#  array([11299.83825279]),
#  array([5458.97642629]),
#  array([4722.9541562]),
#  array([6606.96184877]),
#  array([3873.91062967]),
#  array([4593.49552065]),
#  array([8917.14174531]),
#  array([7395.63448572]),
#  array([6400.2802096]),
#  array([3819.85148328]),
#  array([4559.67918623]),
#  array([4333.05756124]),
#  array([4252.89925684]),
#  array([3763.10046366]),
#  array([9186.27391779]),
#  array([4733.79031387]),
#  array([4363.51112793]),
#  array([3570.04769911]),
#  array([5510.91980626]),
#  array([4941.61109344]),
#  array([4792.71700664]),
#  array([4202.5958293]),
#  array([4625.33025743]),
#  array([4802.82576573]),
#  array([3865.25848854]),
#  array([4563.82417015]),
#  array([59506.07255823]),
#  array([10724.29856952]),
#  array([1314.41325221]),
#  array([621.70327488]),
#  array([1406.71199873]),
#  array([1397.39782509]),
#  array([1087.64789419]),
#  array([7872.71478498]),
#  array([53194.60610103]),
#  array([54476.54473517]),
#  array([4690.02452465]),
#  array([4775.63596352]),
#  array([5021.68301707]),
#  array([4905.02315835]),
#  array([4310.02029428]),
#  array([5019.29658626]),
#  array([5919.28050255]),
#  array([4829.32522327]),
#  array([5259.89111875]),
#  array([10487.62238449]),
#  array([4426.65182361]),
#  array([3033.57130717]),
#  array([3862.36248934]),
#  array([4681.65656869]),
#  array([4638.17823797]),
#  array([4437.71615994]),
#  array([7056.49265707]),
#  array([5080.35112519]),
#  array([6725.78391345]),
#  array([32270.79512651]),
#  array([8374.90967332]),
#  array([5192.42653617]),
#  array([6517.51020357]),
#  array([6411.64095108]),
#  array([5887.67360329]),
#  array([7266.2966902]),
#  array([21048.0078348]),
#  array([63301.55730691]),
#  array([25500.56886374]),
#  array([4109.87116779]),
#  array([4095.48055544]),
#  array([4637.80477651]),
#  array([5041.65584441]),
#  array([6206.59245749]),
#  array([3780.54530166]),
#  array([3608.36389334]),
#  array([3350.8987666]),
#  array([3161.21861654]),
#  array([3873.63910027]),
#  array([4154.54792479]),
#  array([4326.11610717]),
#  array([50563.50321221]),
#  array([64584.06321262]),
#  array([7238.44889561]),
#  array([7923.13154168]),
#  array([7485.73427761]),
#  array([6500.39224089]),
#  array([61721.83107819]),
#  array([5618.37414652]),
#  array([1910.26079215]),
#  array([1324.30530172]),
#  array([1037.91061625]),
#  array([604.6122138]),
#  array([606.90245553]),
#  array([458.19881898]),
#  array([55988.88346514]),
#  array([28491.08512802]),
#  array([6382.36384178]),
#  array([4927.23916214]),
#  array([5978.00393494]),
#  array([6654.35953935]),
#  array([10323.30958526]),
#  array([5528.90901818]),
#  array([5628.6979474]),
#  array([4928.54701031]),
#  array([4184.53011226]),
#  array([4067.69820783]),
#  array([4200.82472138]),
#  array([3846.9124975]),
#  array([4288.34422703]),
#  array([3504.4988707]),
#  array([3761.03729044]),
#  array([4105.67034659]),
#  array([3514.38094844]),
#  array([3814.41002931]),
#  array([4130.04829719]),
#  array([67872.67830166]),
#  array([7116.63813278]),
#  array([3245.23854188]),
#  array([3182.88760043]),
#  array([2709.6716042]),
#  array([2404.38109436]),
#  array([1935.29556788]),
#  array([1702.08396445]),
#  array([1356.30312757]),
#  array([1401.66523485]),
#  array([572.55346104]),
#  array([521.82564326]),
#  array([517.02882757]),
#  array([424.87917979]),
#  array([389.5159258]),
#  array([411.61099847]),
#  array([408.65270826]),
#  array([7151.17051724]),
#  array([51615.80704591]),
#  array([21502.12140367]),
#  array([4116.72187556]),
#  array([3374.40144567]),
#  array([3169.98138493]),
#  array([3788.8307678]),
#  array([4076.47484472]),
#  array([3784.0958047]),
#  array([3704.94979365]),
#  array([7538.88157573]),
#  array([16264.73583378]),
#  array([3952.54667024]),
#  array([4001.05088389]),
#  array([3350.8987666]),
#  array([3202.38811168]),
#  array([2905.64831976]),
#  array([3204.42764621]),
#  array([4411.34098798]),
#  array([4617.25180314]),
#  array([4150.6559612]),
#  array([2951.07029128]),
#  array([3161.30251708]),
#  array([3098.57738349]),
#  array([2861.88202162]),
#  array([2741.53331089]),
#  array([4439.86307679]),
#  array([4416.69961899]),
#  array([4226.57597671]),
#  array([7961.73109521]),
#  array([2796.85015697]),
#  array([2844.93143446]),
#  array([2659.66673005]),
#  array([3759.33540446]),
#  array([3077.25329772]),
#  array([3376.49045234]),
#  array([3579.555091]),
#  array([3639.25219496]),
#  array([3362.17947832]),
#  array([3420.79172259]),
#  array([3612.63260869]),
#  array([4639.50071396]),
#  array([32025.53734336]),
#  array([45112.21880976]),
#  array([1386.53426421]),
#  array([608.63917936]),
#  array([416.31508108]),
#  array([378.93234967]),
#  array([376.31682673]),
#  array([362.26464244]),
#  array([378.18584098]),
#  array([454.26315419]),
#  array([378.33143673]),
#  array([369.8068709]),
#  array([42246.33787869]),
#  array([45004.09676181]),
#  array([4667.06581096]),
#  array([4113.04281717]),
#  array([15762.92989201]),
#  array([3558.15276334]),
#  array([3735.43244536]),
#  array([3687.54005495]),
#  array([3797.87953947]),
#  array([3361.75955268]),
#  array([3700.4715861]),
#  array([2791.3111631]),
#  array([3331.42713062]),
#  array([2916.65939046]),
#  array([4097.34462646]),
#  array([3320.82616691]),
#  array([2751.62192434]),
#  array([3771.98172118]),
#  array([4489.01643091]),
#  array([3480.19257653]),
#  array([2952.32133739]),
#  array([4194.38712563]),
#  array([3885.07093089]),
#  array([2801.92408729]),
#  array([2722.39302662]),
#  array([4046.36253322]),
#  array([2876.56575526]),
#  array([3195.56752733]),
#  array([2659.4316967]),
#  array([2879.17301725]),
#  array([2934.60982637]),
#  array([4053.37203367]),
#  array([61945.95294347]),
#  array([9586.44062162]),
#  array([598.6174541]),
#  array([619.34570071]),
#  array([442.89241604]),
#  array([331.19690476]),
#  array([380.08909157]),
#  array([406.59966208]),
#  array([488.29861663]),
#  array([410.00327215]),
#  array([376.29807726]),
#  array([363.00873472]),
#  array([390.58104349]),
#  array([403.16853357]),
#  array([485.71600185]),
#  array([530.67458086]),
#  ...]

# %%
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2020, 8, 7)
index_cyc = pd.date_range(start, end)
index_cyc
dfrad_cyc = pd.DataFrame(index_cyc, columns = ["date"])
dfrad_cyc

rad_cyc = pd.DataFrame(radius_cyc)

rad_cyc["yhat"]=(k/((math.pi)*(rad_cyc.iloc[:]**2)))

rad_cyc["probability"]=1-(rad_cyc["yhat"]/max(rad_cyc["yhat"]))

rad_cyc['Date'] = dfrad_cyc['date']


rad_cyc[['Date',"probability"]].head(50)
# Out:
#          Date  probability
# 0  2017-01-01     0.988850
# 1  2017-01-02     0.991872
# 2  2017-01-03     0.988746
# 3  2017-01-04     0.992449
# 4  2017-01-05     0.992088
# 5  2017-01-06     0.994358
# 6  2017-01-07     0.993777
# 7  2017-01-08     0.994038
# 8  2017-01-09     0.991972
# 9  2017-01-10     0.992241
# 10 2017-01-11     0.988959
# 11 2017-01-12     0.991990
# 12 2017-01-13     0.991764
# 13 2017-01-14     0.991116
# 14 2017-01-15     0.992601
# 15 2017-01-16     0.991970
# 16 2017-01-17     0.991627
# 17 2017-01-18     0.993163
# 18 2017-01-19     0.993239
# 19 2017-01-20     0.992200
# 20 2017-01-21     0.994004
# 21 2017-01-22     0.995629
# 22 2017-01-23     0.999854
# 23 2017-01-24     0.993360
# 24 2017-01-25     0.998343
# 25 2017-01-26     0.997946
# 26 2017-01-27     0.994246
# 27 2017-01-28     0.994922
# 28 2017-01-29     0.987760
# 29 2017-01-30     0.989106
# 30 2017-01-31     0.995891
# 31 2017-02-01     0.994860
# 32 2017-02-02     0.989543
# 33 2017-02-03     0.991597
# 34 2017-02-04     0.985809
# 35 2017-02-05     0.993157
# 36 2017-02-06     0.989128
# 37 2017-02-07     0.988815
# 38 2017-02-08     0.995703
# 39 2017-02-09     0.990295
# 40 2017-02-10     0.992632
# 41 2017-02-11     0.990544
# 42 2017-02-12     0.993368
# 43 2017-02-13     0.990056
# 44 2017-02-14     0.993536
# 45 2017-02-15     0.991165
# 46 2017-02-16     0.991661
# 47 2017-02-17     0.989110
# 48 2017-02-18     0.990251
# 49 2017-02-19     0.990089

# %%
model_cyc = MDS(n_components=2, dissimilarity='precomputed', random_state=1)
mds_out_cyc = model_cyc.fit_transform(dist_cyc)
dates = df['date'].dt.date.values
x_cyc = mds_out_cyc[:,0]
y_cyc = mds_out_cyc[:,1]

plt.figure(figsize=(15,10))
plt.scatter(x_cyc,y_cyc)
# for i, txt in enumerate(dates):
#     try:
#         plt.annotate(txt, (x[i]+0.3, y[i]+0.3))
#     except:
#         continue
plt.title("year")
plt.show()

# %%
result_outlier_cyc = rad_cyc[rad_cyc['probability'] > 0.999]
result_outlier_cyc

# %%
pd.set_option('display.max_rows', None)
frames = [result_outlier, result_outlier_cyc]
  
result = pd.concat(frames, axis = 1, join = 'outer')
display(result)

# %%
fftval_3 = df.groupby("date").apply(lambda x:  fft(x["Cyclone_Outlet_Gas_draft"].values))
#fftval = fftval[:-1].to_numpy()
fftval_3 = np.array([x for x in fftval_3.values if len(x) == 288])
fftmag_3 = np.abs(fftval_3)
dist_3 = squareform(pdist(np.abs(fftmag_3), 'euclidean'))

# %%
dff_3 = pd.DataFrame(dist_3)
dff_3

# %%
radius_3=[]
for i in range(len(dff)):
    x=dff.sort_values(by=i, axis = 1).iloc[i:i+1,1:37]
    radius.append(x.iloc[:, -1].values)
radius_3

# %%
start = datetime.datetime(2017, 1, 1)
end = datetime.datetime(2020, 8, 7)
index_3 = pd.date_range(start, end)
index_3
dfrad_3 = pd.DataFrame(index_3, columns = ["date"])
dfrad_3
# Out:
#            date
# 0    2017-01-01
# 1    2017-01-02
# 2    2017-01-03
# 3    2017-01-04
# 4    2017-01-05
# 5    2017-01-06
# 6    2017-01-07
# 7    2017-01-08
# 8    2017-01-09
# 9    2017-01-10
# 10   2017-01-11
# 11   2017-01-12
# 12   2017-01-13
# 13   2017-01-14
# 14   2017-01-15
# 15   2017-01-16
# 16   2017-01-17
# 17   2017-01-18
# 18   2017-01-19
# 19   2017-01-20
# 20   2017-01-21
# 21   2017-01-22
# 22   2017-01-23
# 23   2017-01-24
# 24   2017-01-25
# 25   2017-01-26
# 26   2017-01-27
# 27   2017-01-28
# 28   2017-01-29
# 29   2017-01-30
# 30   2017-01-31
# 31   2017-02-01
# 32   2017-02-02
# 33   2017-02-03
# 34   2017-02-04
# 35   2017-02-05
# 36   2017-02-06
# 37   2017-02-07
# 38   2017-02-08
# 39   2017-02-09
# 40   2017-02-10
# 1277 2020-07-01
# 1278 2020-07-02
# 1279 2020-07-03
# 1280 2020-07-04
# 1281 2020-07-05
# 1282 2020-07-06
# 1283 2020-07-07
# 1284 2020-07-08
# 1285 2020-07-09
# 1286 2020-07-10
# 1287 2020-07-11
# 1288 2020-07-12
# 1289 2020-07-13
# 1290 2020-07-14
# 1291 2020-07-15
# 1292 2020-07-16
# 1293 2020-07-17
# 1294 2020-07-18
# 1295 2020-07-19
# 1296 2020-07-20
# 1297 2020-07-21
# 1298 2020-07-22
# 1299 2020-07-23
# 1300 2020-07-24
# 1301 2020-07-25
# 1302 2020-07-26
# 1303 2020-07-27
# 1304 2020-07-28
# 1305 2020-07-29
# 1306 2020-07-30
# 1307 2020-07-31
# 1308 2020-08-01
# 1309 2020-08-02
# 1310 2020-08-03
# 1311 2020-08-04
# 1312 2020-08-05
# 1313 2020-08-06
# 1314 2020-08-07

# %%
rad_3 = pd.DataFrame(radius_3)

rad_3["yhat"]=(k/((math.pi)*(rad_3.iloc[:]**2)))

rad_3["probability"]=1-(rad_3["yhat"]/max(rad_3["yhat"]))

rad_3['Date'] = dfrad_3['date']


rad_3[['Date',"probability"]].head(50)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2728/393292273.py in <module>
#       3 rad_3["yhat"]=(k/((math.pi)*(rad_3.iloc[:]**2)))
#       4
# ----> 5 rad_3["probability"]=1-(rad_3["yhat"]/max(rad_3["yhat"]))
#       6
#       7 rad_3['Date'] = dfrad_3['date']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3472                 if isinstance(self.columns, MultiIndex):
#    3473                     return self._getitem_multilevel(key)
# -> 3474                 return self._get_item_cache(key)
#    3475
#    3476         # Do we have a slicer (on rows)?
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _get_item_cache(self, item)
#    3930
#    3931             loc = self.columns.get_loc(item)
# -> 3932             res = self._ixs(loc, axis=1)
#    3933
#    3934             cache[item] = res
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _ixs(self, i, axis)
#    3439             label = self.columns[i]
#    3440
# -> 3441             col_mgr = self._mgr.iget(i)
#    3442             result = self._box_col_values(col_mgr, i)
#    3443
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in iget(self, i)
#    1019         """
#    1020         block = self.blocks[self.blknos[i]]
# -> 1021         values = block.iget(self.blklocs[i])
#    1022
#    1023         # shortcut for select a single-dim from a 2-dim BM
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in iget(self, i)
#     363         # for "Union[ndarray[Any, Any], ExtensionArray]"; expected type
#     364         # "Union[int, integer[Any]]"
# --> 365         return self.values[i]  # type: ignore[index]
#     366
#     367     def set_inplace(self, locs, values) -> None:
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
# kmeans.cluster_centers_

# %%
# plt.scatter(mds_out[:,0],mds_out[:,1], c=kmeans.labels_)
# plt.scatter(kmeans.cluster_centers_[:,0] ,kmeans.cluster_centers_[:,1], color='black')

# %%
# kmeans.labels_

# %%
# df_mds = pd.DataFrame(mds_out)

# %%
# df_mds

# %%
# df_cluster = pd.DataFrame()
# df_cluster['index'] = df_mds.index.values
# df_cluster['cluster'] = kmeans.labels_

# %%
# df_cluster

# %%
# df = df_cluster.sample(n=3,replace=True)

# %%
# df_cluster.loc[(df_cluster.cluster == 0)]

# %%
# df_cluster.loc[(df_cluster.cluster == 1)]

# %%
# df_cluster.loc[(df_cluster.cluster == 2)]
