# %%
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.2f' % x)
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\ibner\OneDrive\Desktop\StudyMaterials\Learning\2.statistical method\WEEK1\Lok+Sabha_2019.csv")

# %%
df.head(20)
# Out:
#             STATE    CONSTITUENCY                               NAME  WINNER  \
# 0       Telangana        ADILABAD                     SOYAM BAPU RAO       1
# 1       Telangana        ADILABAD                       Godam Nagesh       0
# 2       Telangana        ADILABAD                      RATHOD RAMESH       0
# 3   Uttar Pradesh            AGRA              Satyapal Singh Baghel       1
# 4   Uttar Pradesh            AGRA                   Manoj Kumar Soni       0
# 5   Uttar Pradesh            AGRA                       Preeta Harit       0
# 6     Maharashtra      AHMADNAGAR  Dr. SUJAY RADHAKRISHNA VIKHEPATIL       1
# 7     Maharashtra      AHMADNAGAR            SANGRAM ARUNKAKA JAGTAP       0
# 8     Maharashtra      AHMADNAGAR              SUDHAKAR LAXMAN AVHAD       0
# 9         Gujarat  AHMEDABAD EAST         Patel Hasmukhbhai Somabhai       1
# 10        Gujarat  AHMEDABAD EAST                      Gitaben Patel       0
# 11        Gujarat  AHMEDABAD WEST               DR. KIRIT P. SOLANKI       1
# 12        Gujarat  AHMEDABAD WEST                        RAJU PARMAR       0
# 13        Gujarat  AHMEDABAD WEST     TRIBHOVANDAS KARSANDAS VAGHELA       0
# 14      Rajasthan           AJMER                Bhagirath Chaudhary       1
# 15      Rajasthan           AJMER                  Riju Jhunjhunwala       0
# 16      Rajasthan           AJMER                    Durga Lal Regar       0
# 17      Rajasthan           AJMER                       Vishram Babu       0
# 18  Uttar Pradesh        AKBARPUR             Devendra Singh 'Bhole'       1
# 19  Uttar Pradesh        AKBARPUR                       Nisha Sachan       0
#
#    PARTY        SYMBOL  GENDER  CRIMINAL CASES  AGE CATEGORY      EDUCATION  \
# 0    BJP         Lotus    MALE           52.00   52       ST    Basic Level
# 1    TRS           Car    MALE            0.00   54       ST  Post Graduate
# 2    INC          Hand    MALE            3.00   52       ST    Basic Level
# 3    BJP         Lotus    MALE            5.00   58       SC      Doctorate
# 4    BSP      Elephant    MALE            0.00   47       SC  Post Graduate
# 5    INC          Hand  FEMALE            0.00   54       SC  Post Graduate
# 6    BJP         Lotus    MALE            0.00   37  GENERAL      Doctorate
# 7    NCP         Clock    MALE            1.00   34  GENERAL       Graduate
# 8    VBA  Cup & Saucer    MALE            0.00   62  GENERAL       Graduate
# 9    BJP         Lotus    MALE            0.00   58  GENERAL     Illiterate
# 10   INC          Hand  FEMALE            6.00   38  GENERAL    Basic Level
# 11   BJP         Lotus    MALE            0.00   69       SC  Post Graduate
# 12   INC          Hand    MALE            0.00   68       SC       Graduate
# 13   BSP      Elephant    MALE            0.00   66       SC    Basic Level
# 14   BJP         Lotus    MALE            0.00   64  GENERAL    Basic Level
# 15   INC          Hand    MALE            0.00   40  GENERAL       Graduate
# 16   BSP      Elephant    MALE            0.00   60       SC  Post Graduate
# 17  APoI          Coat    MALE            0.00   60       SC  Post Graduate
# 18   BJP         Lotus    MALE            0.00   64  GENERAL    Basic Level
# 19   BSP      Elephant  FEMALE            0.00   46  GENERAL  Post Graduate
#
#          ASSETS  LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# 0    3099414.00    231450.00         376892           482       377374
# 1   18477888.00    847000.00         318665           149       318814
# 2   36491000.00  15300000.00         314057           181       314238
# 3   74274036.00   8606522.00         644459          2416       646875
# 4  133784385.00  22251891.00         434199          1130       435329
# 5   55075753.00         0.00          44877           272        45149
# 6  168664576.00   2623964.00         696961          7699       704660
# 7   94488381.00  32549132.00         419364          3822       423186
# 8   13949000.00   1400000.00          31644           163        31807
# 9   74699690.00   6252577.00         745810          4024       749834
# 10  40375418.00   3121888.00         312883          2621       315504
# 11  89474039.00         0.00         638241          3381       641622
# 12 262997727.00  18943977.00         317797          2279       320076
# 13   5354000.00         0.00           9909           119        10028
# 14  85101774.00   8319942.00         811091          3985       815076
# 15 853998231.00 306012685.00         397420          1232       398652
# 16  41740458.00    890000.00          13547            71        13618
# 17  25792244.00    268705.00          13036             5        13041
# 18  28546617.00    559965.00         577603          3679       581282
# 19 134448979.00  13619617.00         304553          1587       306140
#
#     OVER TOTAL ELECTORS IN CONSTITUENCY  \
# 0                                 25.33
# 1                                 21.40
# 2                                 21.09
# 3                                 33.38
# 4                                 22.47
# 5                                  2.33
# 6                                 37.86
# 7                                 22.73
# 8                                  1.71
# 9                                 41.38
# 10                                17.41
# 11                                39.04
# 12                                19.48
# 13                                 0.61
# 14                                43.44
# 15                                21.25
# 16                                 0.73
# 17                                 0.70
# 18                                32.91
# 19                                17.33
#
#     OVER TOTAL VOTES POLLED IN CONSTITUENCY  TOTAL ELECTORS
# 0                                     35.47         1489790
# 1                                     29.96         1489790
# 2                                     29.53         1489790
# 3                                     56.46         1937690
# 4                                     38.00         1937690
# 5                                      3.94         1937690
# 6                                     58.43         1861396
# 7                                     35.09         1861396
# 8                                      2.64         1861396
# 9                                     67.01         1811851
# 10                                    28.19         1811851
# 11                                    64.21         1643317
# 12                                    32.03         1643317
# 13                                     1.00         1643317
# 14                                    64.52         1876346
# 15                                    31.56         1876346
# 16                                     1.08         1876346
# 17                                     1.03         1876346
# 18                                    56.62         1766121
# 19                                    29.82         1766121

# %%
df.columns
# Out:
# Index(['STATE', 'CONSTITUENCY', 'NAME', 'WINNER', 'PARTY', 'SYMBOL', 'GENDER',
#        'CRIMINAL CASES', 'AGE', 'CATEGORY', 'EDUCATION', 'ASSETS',
#        'LIABILITIES', 'GENERAL VOTES', 'POSTAL VOTES', 'TOTAL VOTES',
#        'OVER TOTAL ELECTORS IN CONSTITUENCY',
#        'OVER TOTAL VOTES POLLED IN CONSTITUENCY', 'TOTAL ELECTORS'],
#       dtype='object')

# %% [markdown]
# # 1. Which State/UT contributes to the least number of total votes? Which State/UT contributes to the most number of total votes?

# %%
plt.figure(figsize =(20, 10))
df.groupby(df.STATE).sum()['TOTAL VOTES'].sort_values(ascending= False)
# Out:
# STATE
# Uttar Pradesh                83732192
# West Bengal                  55414939
# Maharashtra                  52011437
# Tamil Nadu                   40629837
# Bihar                        38051064
# Madhya Pradesh               35366613
# Karnataka                    33789397
# Rajasthan                    31481301
# Andhra Pradesh               30544833
# Gujarat                      27823175
# Odisha                       23005065
# Kerala                       20010727
# Telangana                    17826332
# Assam                        17318218
# Jharkhand                    14099959
# Punjab                       13156797
# Chhattisgarh                 12918679
# Haryana                      12295211
# NCT OF Delhi                  8505810
# Uttarakhand                   4698459
# Himachal Pradesh              3727232
# Jammu & Kashmir               3424112
# Tripura                       2063655
# Manipur                       1598685
# Meghalaya                     1340215
# Nagaland                       999673
# Goa                            828455
# Puducherry                     753862
# Arunachal Pradesh              640760
# Mizoram                        495137
# Chandigarh                     436583
# Sikkim                         341973
# Andaman & Nicobar Islands      199875
# Dadra & Nagar Haveli           190366
# Daman & Diu                     85190
# Lakshadweep                     46221
# Name: TOTAL VOTES, dtype: int64

# %%
#UttarPradesh contributes to the most number of total votes
#Lakshadweep contributes to the least number of total votes

# %% [markdown]
# # 2. Candidates from which constituency on an average seems to contribute most towards the amount of assets declared? Candidates from which constituency on an average seems to contribute least towards amount of assets declared?

# %%
df.groupby('CONSTITUENCY').mean()['ASSETS'].sort_values(ascending = False)
# Out:
# CONSTITUENCY
# CHEVELLA          3927395902.00
# CHHINDWARA        1655144708.25
# GUNA              1296719487.00
# NELLORE           1289469814.67
# BANGALORE RURAL   1230421937.67
#                        ...
# BOLPUR               4090779.40
# ALIPURDUARS          3895905.50
# GAYA (SC)            3796683.45
# VILUPPURAM           3032143.33
# ALATHUR              2165624.67
# Name: ASSETS, Length: 539, dtype: float64

# %% [markdown]
# # 3. Consider assets and liabilities. Describe and explain both across the Education level? Provide a detailed justification for your answer.

# %% [markdown]
# # 4. Are there any outliers in assets and liabilities across Education level? Back up your answer with a suitable plot/technique.

# %% [markdown]
# # 5. On the basis of the descriptive measure of variability, candidates with what education level shows the most and the least inconsistent behavior in the declared assets?
