# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ibner\OneDrive\Desktop\StudyMaterials\Learning\python\week2\ForbesAmericasTopColleges2019.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9472/911610647.py in <module>
# ----> 1 df = pd.read_csv(r"C:\Users\ibner\OneDrive\Desktop\StudyMaterials\Learning\python\week2\ForbesAmericasTopColleges2019.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9472/964094849.py in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# (650, 17)

# %%
print("The number of rows are:", df.shape[0],"\n The number of column are:",df.shape[1])
# Out:
# The number of rows are: 650
#  The number of column are: 17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      650 non-null    int64
#  1   Name                      650 non-null    object
#  2   City                      650 non-null    object
#  3   State                     650 non-null    object
#  4   Public/Private            650 non-null    object
#  5   Undergraduate Population  650 non-null    int64
#  6   Student Population        650 non-null    int64
#  7   Net Price                 648 non-null    float64
#  8   Average Grant Aid         646 non-null    float64
#  9   Total Annual Cost         650 non-null    int64
#  10  Alumni Salary             635 non-null    float64
#  11  Acceptance Rate           648 non-null    float64
#  12  SAT Lower                 551 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                         0
# Name                         0
# City                         0
# State                        0
# Public/Private               0
# Undergraduate Population     0
# Student Population           0
# Net Price                    2
# Average Grant Aid            4
# Total Annual Cost            0
# Alumni Salary               15
# Acceptance Rate              2
# SAT Lower                   99
# SAT Upper                   99
# ACT Lower                   97
# ACT Upper                   97
# Website                      5
# dtype: int64

# %%
df.drop(['Website', 'SAT Lower', 'SAT Upper', 'ACT Lower','ACT Upper'], axis = 1, inplace = True)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (628, 12)

# %%
df
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 644   645                      Morehouse College      Atlanta    GA
# 645   646            New Mexico State University   Las Cruces    NM
# 646   647               Indiana State University  Terre Haute    IN
# 647   648              Emory &amp; Henry College        Emory    VA
# 649   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
df.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# ...

# %%
df.reset_index(drop=True, inplace = True)

# %%
df
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 623   645                      Morehouse College      Atlanta    GA
# 624   646            New Mexico State University   Las Cruces    NM
# 625   647               Indiana State University  Terre Haute    IN
# 626   648              Emory &amp; Henry College        Emory    VA
# 627   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      628 non-null    int64
#  1   Name                      628 non-null    object
#  2   City                      628 non-null    object
#  3   State                     628 non-null    object
#  4   Public/Private            628 non-null    object
#  5   Undergraduate Population  628 non-null    int64
#  6   Student Population        628 non-null    int64
#  7   Net Price                 628 non-null    float64
#  8   Average Grant Aid         628 non-null    float64
#  9   Total Annual Cost         628 non-null    int64
#  10  Alumni Salary             628 non-null    float64
#  11  Acceptance Rate           628 non-null    float64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 59.0+ KB

# %%
df.describe()
# Out:
#              Rank  Undergraduate Population  Student Population     Net Price  \
# count  628.000000                628.000000          628.000000    628.000000
# mean   322.122611              10235.472930        12312.912420  22481.570064
# std    185.360460              11228.048723        13246.660229   8099.771637
# min      1.000000                323.000000          406.000000   1298.000000
# 25%    161.750000               2062.750000         2294.500000  16476.000000
# 50%    321.500000               4825.500000         6538.500000  22065.000000
# 75%    479.250000              15867.000000        18357.250000  27880.750000
# max    650.000000              65100.000000        75044.000000  47270.000000
#
#        Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate
# count         628.000000         628.000000     628.000000       628.000000
# mean        19971.522293       50722.579618   98616.242038        61.721338
# ...

# %%
df.Rank.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
top5 = df.Name.head()
top5
# Out:
# 0                       Harvard University
# 1                      Stanford University
# 2                          Yale University
# 3    Massachusetts Institute of Technology
# 4                     Princeton University
# Name: Name, dtype: object

# %%
df[['Name','State','City']].head()
# Out:
#                                     Name State       City
# 0                     Harvard University    MA  Cambridge
# 1                    Stanford University    CA   Stanford
# 2                        Yale University    CT  New Haven
# 3  Massachusetts Institute of Technology    MA  Cambridge
# 4                   Princeton University    NJ  Princeton

# %%
df.iloc[0:5, 0:4]
# Out:
#    Rank                                   Name       City State
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ

# %%
df.State.unique()
# Out:
# array(['MA', 'CA', 'CT', 'NJ', 'PA', 'RI', 'NC', 'NH', 'NY', 'DC', 'IL',
#        'IN', 'MI', 'TX', 'MD', 'ME', 'TN', 'MO', 'VA', 'VT', 'MN', 'GA',
#        'WA', 'WI', 'FL', 'OH', 'IA', 'CO', 'UT', 'OR', 'LA', 'SC', 'DE',
#        'AL', 'AZ', 'OK', 'NE', 'KY', 'KS', 'AR', 'WY', 'NV', 'MS', 'ND',
#        'HI', 'MT', 'SD', 'NM', 'ID', 'WV', 'AK'], dtype=object)

# %%
df.State.nunique()
# Out:
# 51

# %%
df['Public/Private'].value_counts()
# Out:
# Private    384
# Public     244
# Name: Public/Private, dtype: int64

# %%
df[['State', 'City', 'Public/Private']].value_counts()
# Out:
# State  City        Public/Private
# NY     New York    Private           9
# MA     Boston      Private           6
# NY     New York    Public            5
# DC     Washington  Private           5
# CA     Claremont   Private           5
#                                     ..
# KY     Louisville  Public            1
#                    Private           1
#        Lexington   Public            1
#                    Private           1
# WY     Laramie     Public            1
# Length: 536, dtype: int64

# %%
df
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 623   645                      Morehouse College      Atlanta    GA
# 624   646            New Mexico State University   Las Cruces    NM
# 625   647               Indiana State University  Terre Haute    IN
# 626   648              Emory &amp; Henry College        Emory    VA
# 627   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
df.groupby(by = 'State').Name.nunique().sort_values(ascending = False)
# Out:
# State
# NY    64
# CA    56
# PA    39
# MA    31
# OH    29
# TX    25
# IL    25
# FL    20
# NC    19
# VA    18
# MN    18
# IN    18
# MI    16
# TN    14
# GA    14
# WI    13
# NJ    13
# IA    13
# MO    12
# WA    12
# KY    12
# MD    12
# CO    11
# OR    11
# CT     9
# SC     8
# LA     8
# AL     7
# RI     7
# OK     6
# NE     6
# DC     5
# ME     5
# MS     5
# SD     4
# AR     4
# ID     4
# AZ     4
# MT     4
# UT     4
# VT     4
# NM     3
# NH     3
# KS     3
# AK     2
# NV     2
# ND     2
# HI     1
# DE     1
# WV     1
# WY     1
# Name: Name, dtype: int64

# %%
df['Percentage UG'] = round(df['Undergraduate Population']/df['Student Population'] * 100)

# %%
df
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 623   645                      Morehouse College      Atlanta    GA
# 624   646            New Mexico State University   Las Cruces    NM
# 625   647               Indiana State University  Terre Haute    IN
# 626   648              Emory &amp; Henry College        Emory    VA
# 627   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
df[['Name', 'Percentage UG']].sort_values(by='Percentage UG', ascending = False).head()
# Out:
#                                     Name  Percentage UG
# 105  Rose-Hulman Institute of Technology          100.0
# 256                 Wheaton College (MA)          100.0
# 338                  St. Norbert College          100.0
# 360  University of Wisconsin, Eau Claire          100.0
# 246         Saint John's University (MN)          100.0

# %%
df[['Name', 'Average Grant Aid']].sort_values(by ='Average Grant Aid', ascending = False).head()
# Out:
#                    Name  Average Grant Aid
# 2       Yale University            50897.0
# 1   Stanford University            50134.0
# 0    Harvard University            49870.0
# 26      Amherst College            49467.0
# 13  Columbia University            49185.0

# %%
df.sort_values(by ='Average Grant Aid', ascending = False).Name.head()
# Out:
# 2         Yale University
# 1     Stanford University
# 0      Harvard University
# 26        Amherst College
# 13    Columbia University
# Name: Name, dtype: object

# %%
df
# Out:
#      Rank                                   Name         City State  \
# 0       1                     Harvard University    Cambridge    MA
# 1       2                    Stanford University     Stanford    CA
# 2       3                        Yale University    New Haven    CT
# 3       4  Massachusetts Institute of Technology    Cambridge    MA
# 4       5                   Princeton University    Princeton    NJ
# ..    ...                                    ...          ...   ...
# 623   645                      Morehouse College      Atlanta    GA
# 624   646            New Mexico State University   Las Cruces    NM
# 625   647               Indiana State University  Terre Haute    IN
# 626   648              Emory &amp; Henry College        Emory    VA
# 627   650                        Catawba College    Salisbury    NC
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# ...

# %%
round(df[df.State == 'CA']['Undergraduate Population'].mean())
# Out:
# 13187

# %%
df.sort_values(by= 'Acceptance Rate', ascending = True).head()
# Out:
#      Rank                  Name       City State Public/Private  \
# 0       1    Harvard University  Cambridge    MA        Private
# 1       2   Stanford University   Stanford    CA        Private
# 4       5  Princeton University  Princeton    NJ        Private
# 114   119  The Juilliard School   New York    NY        Private
# 2       3       Yale University  New Haven    CT        Private
#
#      Undergraduate Population  Student Population  Net Price  \
# 0                       13844               31120    14327.0
# 1                        8402               17534    13261.0
# 4                        5659                8273     9327.0
# 114                       590                 927    32829.0
# 2                        6483               12974    18627.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 0              49870.0              69600       146800.0              5.0
# ...

# %%
df[df['Name'].str.contains("Art")]
# Out:
#      Rank                               Name           City State  \
# 295   303  Maryland Institute College of Art      Baltimore    MD
# 393   402   California Institute of the Arts  Santa Clarita    CA
#
#     Public/Private  Undergraduate Population  Student Population  Net Price  \
# 295        Private                      2041                2128    38763.0
# 393        Private                       991                1498    46101.0
#
#      Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# 295            18939.0              62850        84500.0             62.0
# 393            15401.0              68993        91000.0             24.0
#
#      Percentage UG
# 295           96.0
# 393           66.0

# %%
df1 = df.copy()

# %%
df1['Alumni Salary Level'] = pd.cut(df1['Alumni Salary'], 3, labels = ["L", "M", "H"])

# %%
df1.head()
# Out:
#    Rank                                   Name       City State  \
# 0     1                     Harvard University  Cambridge    MA
# 1     2                    Stanford University   Stanford    CA
# 2     3                        Yale University  New Haven    CT
# 3     4  Massachusetts Institute of Technology  Cambridge    MA
# 4     5                   Princeton University  Princeton    NJ
#
#   Public/Private  Undergraduate Population  Student Population  Net Price  \
# 0        Private                     13844               31120    14327.0
# 1        Private                      8402               17534    13261.0
# 2        Private                      6483               12974    18627.0
# 3        Private                      4680               11466    20771.0
# 4        Private                      5659                8273     9327.0
#
#    Average Grant Aid  Total Annual Cost  Alumni Salary  Acceptance Rate  \
# ...

# %%
df1['Alumni Salary Level'].value_counts()
# Out:
# L    383
# M    217
# H     28
# Name: Alumni Salary Level, dtype: int64

# %%
round(df1.groupby('Alumni Salary Level')['Alumni Salary'].mean(),2)
# Out:
# Alumni Salary Level
# L     89835.77
# M    109086.64
# H    137575.00
# Name: Alumni Salary, dtype: float64

# %%
df2 = df1[df1['Alumni Salary Level'] == 'H']

# %%
df2.describe(include = 'all').T
# Out:
#                          count unique                 top freq          mean  \
# Rank                      28.0    NaN                 NaN  NaN     68.857143
# Name                        28     28  Harvard University    1           NaN
# City                        28     27           Cambridge    2           NaN
# State                       28     12                  CA    6           NaN
# Public/Private              28      2             Private   22           NaN
# Undergraduate Population  28.0    NaN                 NaN  NaN   6389.535714
# Student Population        28.0    NaN                 NaN  NaN  10603.321429
# Net Price                 28.0    NaN                 NaN  NaN  25288.571429
# Average Grant Aid         28.0    NaN                 NaN  NaN  32340.535714
# Total Annual Cost         28.0    NaN                 NaN  NaN  62952.464286
# Alumni Salary             28.0    NaN                 NaN  NaN      137575.0
# ...
